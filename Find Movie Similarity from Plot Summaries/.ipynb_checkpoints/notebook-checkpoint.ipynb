# %% [markdown]
# ## 1. Import and observe dataset
# <p>We all love watching movies! There are some movies we like, some we don't. Most people have a preference for movies of a similar genre. Some of us love watching action movies, while some of us like watching horror. Some of us like watching movies that have ninjas in them, while some of us like watching superheroes.</p>
# <p>Movies within a genre often share common base parameters. Consider the following two movies:</p>
# <p><img style="margin:5px 20px 5px 1px; height: 250px; display: inline-block;" alt="2001: A Space Odyssey" src="https://assets.datacamp.com/production/project_648/img/movie1.jpg">
# <img style="margin:5px 20px 5px 1px; height: 250px; display: inline-block;" alt="Close Encounters of the Third Kind" src="https://assets.datacamp.com/production/project_648/img/movie2.jpg"></p>
# <p>Both movies, <em>2001: A Space Odyssey</em> and <em>Close Encounters of the Third Kind</em>, are movies based on aliens coming to Earth. I've seen both, and they indeed share many similarities. We could conclude that both of these fall into the same genre of movies based on intuition, but that's no fun in a data science context. In this notebook, we will quantify the similarity of movies based on their plot summaries available on IMDb and Wikipedia, then separate them into groups, also known as clusters. We'll create a dendrogram to represent how closely the movies are related to each other.</p>
# <p>Let's start by importing the dataset and observing the data provided.</p>

# %%
# Import modules
import numpy as np
import pandas as pd
import nltk

# Set seed for reproducibility
np.random.seed(5)

# Read in IMDb and Wikipedia movie data (both in same file)
movies_df = pd.read_csv("datasets/movies_ratings.csv")

print("Number of movies loaded: %s " % (len(movies_df)))

# Display the data
movies_df
# Out:
# Number of movies loaded: 4337
#       adult                              belongs_to_collection    budget  \
# 0     False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1     False                                                NaN  60000000
# 2     False                                                NaN  52000000
# 3     False                                                NaN  18000000
# 4     False                                                NaN  33000000
# 5     False                                                NaN   6000000
# 6     False                                                NaN         0
# 7     False                                                NaN         0
# 8     False                                                NaN         0
# 9     False                                                NaN         0
# 10    False                                                NaN   3000000
# 11    False                                                NaN  72000000
# 12    False                                                NaN   1300000
# 13    False                                                NaN         0
# 14    False                                                NaN         0
# 15    False                                                NaN         0
# 16    False                                                NaN         0
# 17    False                                                NaN         0
# 18    False                                                NaN         0
# 19    False  {'id': 123800, 'name': 'Before... Collection',...   2500000
# 20    False                                                NaN         0
# 21    False                                                NaN    700000
# 22    False  {'id': 10, 'name': 'Star Wars Collection', 'po...  11000000
# 23    False  {'id': 300546, 'name': 'Once were Warriors Col...         0
# 24    False                                                NaN  16000000
# 25    False                                                NaN   8000000
# 26    False  {'id': 131, 'name': 'Three Colors Collection',...         0
# 27    False  {'id': 131, 'name': 'Three Colors Collection',...         0
# 28    False                                                NaN  25000000
# 29    False                                                NaN         0
# ...     ...                                                ...       ...
# 4307  False                                                NaN         0
# 4308  False                                                NaN         0
# 4309  False                                                NaN         0
# 4310  False                                                NaN         0
# 4311  False                                                NaN         0
# 4312  False                                                NaN         0
# 4313  False                                                NaN         0
# 4314  False                                                NaN         0
# 4315  False  {'id': 466463, 'name': 'Descendants Collection...         0
# 4316  False                                                NaN         0
# 4317  False                                                NaN         0
# 4318  False                                                NaN         0
# 4319  False                                                NaN         0
# 4320  False                                                NaN         0
# 4321  False                                                NaN         0
# 4322  False                                                NaN         0
# 4323  False                                                NaN         0
# 4324  False                                                NaN         0
# 4325  False                                                NaN         0
# 4326  False                                                NaN         0
# 4327  False                                                NaN         0
# 4328  False                                                NaN         0
# 4329  False                                                NaN         0
# 4330  False  {'id': 477208, 'name': 'DC Super Hero Girls Co...         0
# 4331  False                                                NaN         0
# 4332  False                                                NaN   1254040
# 4333  False                                                NaN         0
# 4334  False                                                NaN         0
# 4335  False                                                NaN         0
# 4336  False                                                NaN         0
#
#                                                  genres  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1     [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 3     [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...
# 4     [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 5     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 6     [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 7     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 8     [{'id': 10751, 'name': 'Family'}, {'id': 18, '...
# 9                        [{'id': 35, 'name': 'Comedy'}]
# 10                        [{'id': 18, 'name': 'Drama'}]
# 11    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 12    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 13                        [{'id': 18, 'name': 'Drama'}]
# 14    [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 15                  [{'id': 99, 'name': 'Documentary'}]
# 16    [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...
# 17    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 18    [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 19    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 20    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 21                  [{'id': 99, 'name': 'Documentary'}]
# 22    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 23                        [{'id': 18, 'name': 'Drama'}]
# 24    [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 25    [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 26    [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 27    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 28    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 29    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 4307                [{'id': 99, 'name': 'Documentary'}]
# 4308  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 4309                   [{'id': 53, 'name': 'Thriller'}]
# 4310                [{'id': 99, 'name': 'Documentary'}]
# 4311                      [{'id': 18, 'name': 'Drama'}]
# 4312                     [{'id': 28, 'name': 'Action'}]
# 4313                     [{'id': 35, 'name': 'Comedy'}]
# 4314                [{'id': 99, 'name': 'Documentary'}]
# 4315  [{'id': 10770, 'name': 'TV Movie'}, {'id': 107...
# 4316                     [{'id': 35, 'name': 'Comedy'}]
# 4317                  [{'id': 16, 'name': 'Animation'}]
# 4318  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 4319  [{'id': 35, 'name': 'Comedy'}, {'id': 99, 'nam...
# 4320                      [{'id': 18, 'name': 'Drama'}]
# 4321  [{'id': 10402, 'name': 'Music'}, {'id': 35, 'n...
# 4322                                                 []
# 4323  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 4324                      [{'id': 18, 'name': 'Drama'}]
# 4325                [{'id': 99, 'name': 'Documentary'}]
# 4326  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4327                      [{'id': 18, 'name': 'Drama'}]
# 4328                [{'id': 99, 'name': 'Documentary'}]
# 4329                                                 []
# 4330                  [{'id': 16, 'name': 'Animation'}]
# 4331  [{'id': 99, 'name': 'Documentary'}, {'id': 107...
# 4332  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 4333                      [{'id': 18, 'name': 'Drama'}]
# 4334  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 4335  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 4336                      [{'id': 18, 'name': 'Drama'}]
#
#                                                homepage      id    imdb_id  \
# 0                  http://toystory.disney.com/toy-story     862  tt0114709
# 1                                                   NaN     949  tt0113277
# 2                                                   NaN     524  tt0112641
# 3                                                   NaN     902  tt0112682
# 4                            http://www.sevenmovie.com/     807  tt0114369
# 5     http://www.mgm.com/#/our-titles/2083/The-Usual...     629  tt0114814
# 6                                                   NaN   49133  tt0110299
# 7                                                   NaN   11010  tt0110877
# 8                                                   NaN   46785  tt0112445
# 9                                                   NaN   40154  tt0113403
# 10                                                  NaN     406  tt0113247
# 11                                                  NaN     197  tt0112573
# 12                                                  NaN     103  tt0075314
# 13                                                  NaN   71754  tt0113774
# 14                                                  NaN   11104  tt0109424
# 15                                                  NaN   26564  tt0109508
# 16                                                  NaN   58372  tt0114241
# 17                                                  NaN    5967  tt0058450
# 18                                                  NaN   19155  tt0110882
# 19                                                  NaN      76  tt0112471
# 20                                                  NaN   10451  tt0111797
# 21                                                  NaN   14275  tt0110057
# 22    http://www.starwars.com/films/star-wars-episod...      11  tt0076759
# 23                                                  NaN     527  tt0110729
# 24                                                  NaN     101  tt0110413
# 25                                                  NaN     680  tt0110912
# 26                                                  NaN     110  tt0111495
# 27                                                  NaN     108  tt0108394
# 28                                                  NaN     278  tt0111161
# 29                                                  NaN   31439  tt0110081
# ...                                                 ...     ...        ...
# 4307                             http://24x36movie.com/  385305  tt5003654
# 4308                                                NaN  412103  tt5950978
# 4309                                                NaN  437830  tt6194850
# 4310                                                NaN  411516  tt5135434
# 4311                                                NaN  280640  tt3565174
# 4312                                                NaN   49074  tt0139876
# 4313                                                NaN   28469  tt0273646
# 4314       http://channel.nationalgeographic.com/la-92/  450875  tt6794424
# 4315                                                NaN  417320  tt5117876
# 4316  http://www.hbo.com/comedy/chris-gethard-career...  454787  tt6794460
# 4317                          https://www.pixar.com/lou  433471  tt6267732
# 4318                                                NaN  104308  tt0095728
# 4319             http://www.kinoswiat.pl/film_hiway.asp   60153  tt0794290
# 4320                                                NaN   79343  tt0425990
# 4321                                                NaN  101801  tt0282917
# 4322                                                NaN   80284  tt0969746
# 4323                                                NaN   81313  tt0379063
# 4324                                                NaN  120831  tt0018107
# 4325                                                NaN  401408  tt5845320
# 4326                                                NaN  434166  tt5609734
# 4327                                                NaN  269981  tt0122737
# 4328                                                NaN  188421  tt1738321
# 4329                                                NaN  173874  tt0113769
# 4330                                                NaN  460135  tt7158814
# 4331                                                NaN   91563  tt0478101
# 4332                                    http://lmtr.fi/  468707  tt5742932
# 4333                                                NaN  258907  tt0071450
# 4334                                                NaN  455661  tt6969946
# 4335                                                NaN   49279  tt0000359
# 4336                                                NaN  111109  tt2028550
#
#      original_language                                     original_title  \
# 0                   en                                          Toy Story
# 1                   en                                               Heat
# 2                   en                                             Casino
# 3                   fr                        La CitÃ© des Enfants Perdus
# 4                   en                                              Se7en
# 5                   en                                 The Usual Suspects
# 6                   it                                           Lamerica
# 7                   it                                         Il postino
# 8                   fa                              Ø¨Ø§Ø¯Ú©Ù†Ú© Ø³ÙÛŒØ¯
# 9                   en                                 A Midwinter's Tale
# 10                  fr                                           La Haine
# 11                  en                                         Braveheart
# 12                  en                                        Taxi Driver
# 13                  en                                  Margaret's Museum
# 14                  cn                                       é‡æ…¶æ£®æž—
# 15                  en                                              Crumb
# 16                  en                                           Reckless
# 17                  fr                        Les parapluies de Cherbourg
# 18                  en                                    Before the Rain
# 19                  en                                     Before Sunrise
# 20                  zh                                       é£²é£Ÿç”·å¥³
# 21                  en                                        Hoop Dreams
# 22                  en                                          Star Wars
# 23                  en                                 Once Were Warriors
# 24                  fr                                              LÃ©on
# 25                  en                                       Pulp Fiction
# 26                  fr                             Trois couleurs : Rouge
# 27                  fr                              Trois couleurs : Bleu
# 28                  en                           The Shawshank Redemption
# 29                  zh                                             æ´»ç€
# ...                ...                                                ...
# 4307                en                                             24Ã—36
# 4308                en  Rick and Morty: State of Georgia Vs. Denver Fe...
# 4309                en                                             Zero 3
# 4310                de                                Ein deutsches Leben
# 4311                fr                                           Geronimo
# 4312                ta                                             Baasha
# 4313                de                                      Der Herr Karl
# 4314                en                                              LA 92
# 4315                en                                      Descendants 2
# 4316                en                      Chris Gethard: Career Suicide
# 4317                en                                                Lou
# 4318                it                                  Il nido del ragno
# 4319                en                                             Hi Way
# 4320                fr                                 Les fourmis rouges
# 4321                cs                                        Rok ÄÃ¡bla
# 4322                es                                La sangre iluminada
# 4323                en                                         Zmruz oczy
# 4324                en                                               Love
# 4325                en  Leslie Caron, franÃ§aise Ã  Hollywood, amÃ©ric...
# 4326                de                       Es war einmal in Deutschland
# 4327                en                                   Twelve Angry Men
# 4328                en               A History of Horror with Mark Gatiss
# 4329                en                  The Many Faces of Christopher Lee
# 4330                en              LEGO DC Super Hero Girls: Brain Drain
# 4331                en                                          Black Sun
# 4332                fi                  Lauri MÃ¤ntyvaaran tuuheet ripset
# 4333                en                                        Dyketactics
# 4334                en                                     In a Heartbeat
# 4335                fr                  L'Homme Ã  la tÃªte de caoutchouc
# 4336                tl                                Siglo ng Pagluluwal
#
#                                                overview  ...  release_date  \
# 0     Led by Woody, Andy's toys live happily in his ...  ...    10/30/1995
# 1     Obsessive master thief, Neil McCauley leads a ...  ...    12/15/1995
# 2     The life of the gambling paradise â€“ Las Vega...  ...    11/22/1995
# 3     A scientist in a surrealist society kidnaps ch...  ...     5/16/1995
# 4     Two homicide detectives are on a desperate hun...  ...     9/22/1995
# 5     Held in an L.A. interrogation room, Verbal Kin...  ...     7/19/1995
# 6     Fiore, an Italian conman, arrives in post Comm...  ...      1/1/1994
# 7     Simple Italian postman learns to love poetry w...  ...     9/22/1994
# 8     Several people try to take advantage of a litt...  ...      1/1/1995
# 9     Out of work actor Joe volunteers to help try a...  ...     12/1/1995
# 10    Aimlessly whiling away their days in the concr...  ...     5/31/1995
# 11    Enraged at the slaughter of Murron, his new br...  ...     5/24/1995
# 12    A mentally unstable Vietnam War veteran works ...  ...      2/7/1976
# 13    In a town where half the men die down the coal...  ...     9/13/1995
# 14    Every day, Cop 223 buys a can of pineapple wit...  ...     7/14/1994
# 15    This movie chronicles the life and times of R....  ...     9/10/1994
# 16    On Christmas eve, a relentlessly cheerful woma...  ...    11/17/1995
# 17    This simple romantic tragedy begins in 1957. G...  ...     2/19/1964
# 18    The circularity of violence seen in a story th...  ...      6/9/1994
# 19    A dialogue marathon of a film, this fairytale ...  ...     1/27/1995
# 20    The film tells the story of a retired and wido...  ...      8/3/1994
# 21    This documentary follows two inner-city Chicag...  ...     9/12/1994
# 22    Princess Leia is captured and held hostage by ...  ...     5/25/1977
# 23    A drama about a Maori family lving in Auckland...  ...      9/2/1994
# 24    Leon, the top hit man in New York, has earned ...  ...     9/14/1994
# 25    A burger-loving hit man, his philosophical par...  ...     9/10/1994
# 26    Red This is the third film from the trilogy by...  ...     5/27/1994
# 27    A woman struggles to find a way to live her li...  ...     1/10/1993
# 28    Framed in the 1940s for the double murder of h...  ...     9/23/1994
# 29    Fugui and Jiazhen endure tumultuous events in ...  ...     6/30/1994
# ...                                                 ...  ...           ...
# 4307  A documentary exploring the birth, death and r...  ...      3/5/2016
# 4308  A faithful, word-for-word recreation of one co...  ...     7/24/2016
# 4309                Lithuanian politics Tarantino style  ...     1/27/2017
# 4310  Brunhilde Pomsel describes herself as an "apol...  ...    10/15/2016
# 4311  South of France. In the sultry August heat, Ge...  ...    10/15/2014
# 4312  Auto rickshaw driver Manickam avoids violence ...  ...     1/15/1995
# 4313                                 No overview found.  ...    11/15/1961
# 4314  Twenty-five years after the verdict in the Rod...  ...     4/28/2017
# 4315  When the pressure to be royal becomes too much...  ...     7/21/2017
# 4316  A comedy about depression, alcoholism, suicide...  ...      5/6/2017
# 4317  A Pixar short about a lost-and-found box and t...  ...     6/16/2017
# 4318  A young professor travels to Budapest to locat...  ...     8/25/1988
# 4319  Two young aspiring filmmakers, director Jaco a...  ...      5/2/2006
# 4320                                                NaN  ...    11/14/2007
# 4321  Documentary maker Jan Holman follows the ultra...  ...      3/7/2002
# 4322  Six characters narrate their complex existence...  ...     4/25/2008
# 4323  The story of a spirited ten-year-old girl who ...  ...    10/24/2003
# 4324  In Imperial Russia, Anna Karenina falls in lov...  ...    11/28/1927
# 4325  Leslie Caron, beloved star of Gigi and An Amer...  ...     6/28/2016
# 4326  David Berman and his friends, all Holocaust su...  ...      4/6/2017
# 4327  Twelve Angry Men is a 1954 teleplay by Reginal...  ...     9/20/1954
# 4328  Mark Gatiss examines the history of the horror...  ...    10/25/2010
# 4329  Christopher Lee talks about his film career, w...  ...      1/1/1996
# 4330  When Supergirl, Wonder Woman, Batgirl, Bumbleb...  ...     8/30/2017
# 4331  Blurred images illustrate the narration of Hug...  ...     9/12/2005
# 4332                                                NaN  ...     7/28/2017
# 4333  Born in Los Angeles but a New Yorker by choice...  ...      1/1/1974
# 4334  A closeted boy runs the risk of being outed by...  ...      6/1/2017
# 4335  A chemist in his laboratory places upon a tabl...  ...      1/1/1901
# 4336  An artist struggles to finish his work while a...  ...    11/17/2011
#
#         revenue runtime                                   spoken_languages  \
# 0     373554033    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1     187436818   170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2     116112375   178.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       1738611   108.0  [{'iso_639_1': 'cn', 'name': 'å¹¿å·žè¯ / å»£å...
# 4     327311859   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5      23341568   106.0  [{'iso_639_1': 'es', 'name': 'EspaÃ±ol'}, {'is...
# 6             0   116.0  [{'iso_639_1': 'sq', 'name': 'shqip'}, {'iso_6...
# 7             0   108.0  [{'iso_639_1': 'it', 'name': 'Italiano'}, {'is...
# 8             0    85.0        [{'iso_639_1': 'fa', 'name': 'ÙØ§Ø±Ø³ÛŒ'}]
# 9             0    99.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10            0    98.0         [{'iso_639_1': 'fr', 'name': 'FranÃ§ais'}]
# 11    210000000   177.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 12     28262574   114.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 13            0   114.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14            0   102.0  [{'iso_639_1': 'cn', 'name': 'å¹¿å·žè¯ / å»£å...
# 15      3174695   119.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 16            0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 17            0    91.0         [{'iso_639_1': 'fr', 'name': 'FranÃ§ais'}]
# 18       763847   113.0  [{'iso_639_1': 'sq', 'name': 'shqip'}, {'iso_6...
# 19      5535405   105.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 20      7294403   123.0         [{'iso_639_1': 'zh', 'name': 'æ™®é€šè¯'}]
# 21      7830611   171.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 22    775398007   121.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 23      2201126    99.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 24     45284974   110.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 25    213928762   154.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 26            0    99.0         [{'iso_639_1': 'fr', 'name': 'FranÃ§ais'}]
# 27            0    98.0  [{'iso_639_1': 'fr', 'name': 'FranÃ§ais'}, {'i...
# 28     28341469   142.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 29            0   125.0         [{'iso_639_1': 'zh', 'name': 'æ™®é€šè¯'}]
# ...         ...     ...                                                ...
# 4307          0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4308          0    10.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4309          0    90.0                                                 []
# 4310          0   107.0           [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# 4311          0   107.0         [{'iso_639_1': 'fr', 'name': 'FranÃ§ais'}]
# 4312   15000000   145.0   [{'iso_639_1': 'ta', 'name': 'à®¤à®®à®¿à®´à¯'}]
# 4313          0    60.0           [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# 4314          0   114.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4315          0   111.0             [{'iso_639_1': 'da', 'name': 'Dansk'}]
# 4316          0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4317          0     6.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4318          0    86.0          [{'iso_639_1': 'it', 'name': 'Italiano'}]
# 4319          0    89.0            [{'iso_639_1': 'pl', 'name': 'Polski'}]
# 4320          0     0.0                                                 []
# 4321          0    88.0           [{'iso_639_1': 'cs', 'name': 'ÄŒeskÃ½'}]
# 4322          0   104.0          [{'iso_639_1': 'es', 'name': 'EspaÃ±ol'}]
# 4323          0    88.0                                                 []
# 4324          0    81.0                                                 []
# 4325          0    53.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4326          0   102.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4327          0    51.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4328          0   177.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4329          0    60.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4330          0     0.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4331          0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4332          0    90.0             [{'iso_639_1': 'fi', 'name': 'suomi'}]
# 4333          0     4.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4334          0     4.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4335          0     3.0                                                 []
# 4336          0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
#
#         status                                            tagline  \
# 0     Released                                                NaN
# 1     Released                           A Los Angeles Crime Saga
# 2     Released                   No one stays at the top forever.
# 3     Released          Where happily ever after is just a dream.
# 4     Released              Seven deadly sins. Seven ways to die.
# 5     Released       Five Criminals. One Line Up. No Coincidence.
# 6     Released                                                NaN
# 7     Released                                                NaN
# 8     Released                                                NaN
# 9     Released  The drama. The passion. The intrigue... And th...
# 10    Released            Three Young Friends... One Last Chance.
# 11    Released         Every man dies. Not every man truly lives.
# 12    Released  On every street in every city, there's a nobod...
# 13    Released  She found a way to preserve her memories forever.
# 14    Released                      What a difference a day makes
# 15    Released              Weird sex Â· Obsession Â· Comic books
# 16    Released                   The most twisted Christmas ever.
# 17    Released       a film for all the young lovers of the world
# 18    Released  Once You Know The Faces You Will Begin To Unde...
# 19    Released  Can the greatest romance of your life last onl...
# 20    Released                                                NaN
# 21    Released                       An Extraordinary True Story.
# 22    Released       A long time ago in a galaxy far, far away...
# 23    Released  A family in crisis, a life in chaos... Nothing...
# 24    Released  If you want a job done well, hire a professional.
# 25    Released  Just because you are a character doesn't mean ...
# 26    Released                                                NaN
# 27    Released                                                NaN
# 28    Released  Fear can hold you prisoner. Hope can set you f...
# 29    Released                                                NaN
# ...        ...                                                ...
# 4307  Released                       A movie about movie posters.
# 4308  Released                                                NaN
# 4309  Released                                                NaN
# 4310  Released                                                NaN
# 4311  Released                                                NaN
# 4312  Released                                                NaN
# 4313  Released                                                NaN
# 4314  Released                               The past is prologue
# 4315  Released                                    Long live evil.
# 4316  Released         Comedy can be found in the darkest places.
# 4317  Released                                                NaN
# 4318  Released                                                NaN
# 4319  Released                You gotta see it two to three times
# 4320  Released                                                NaN
# 4321  Released                          A sad comedy about angels
# 4322  Released                                                NaN
# 4323  Released                                                NaN
# 4324  Released  Love Makes the World Go 'Round. It Will Spin L...
# 4325  Released                                                NaN
# 4326  Released                                                NaN
# 4327  Released                                                NaN
# 4328  Released                                                NaN
# 4329  Released                                                NaN
# 4330  Released                                                NaN
# 4331  Released                                                NaN
# 4332  Released                                                NaN
# 4333  Released                                                NaN
# 4334  Released               The Heart Wants What The Heart Wants
# 4335  Released                                                NaN
# 4336  Released                                                NaN
#
#                                                   title  video vote_average  \
# 0                                             Toy Story  False          7.7
# 1                                                  Heat  False          7.7
# 2                                                Casino  False          7.8
# 3                             The City of Lost Children  False          7.6
# 4                                                 Se7en  False          8.1
# 5                                    The Usual Suspects  False          8.1
# 6                                              Lamerica  False          7.7
# 7                                           The Postman  False          7.6
# 8                                     The White Balloon  False          7.5
# 9                                    A Midwinter's Tale  False          7.5
# 10                                             La Haine  False          7.9
# 11                                           Braveheart  False          7.7
# 12                                          Taxi Driver  False          8.1
# 13                                    Margaret's Museum  False          7.5
# 14                                    Chungking Express  False          7.9
# 15                                                Crumb  False          7.6
# 16                                             Reckless  False         10.0
# 17                           The Umbrellas of Cherbourg  False          7.6
# 18                                      Before the Rain  False          7.7
# 19                                       Before Sunrise  False          7.7
# 20                                  Eat Drink Man Woman  False          7.5
# 21                                          Hoop Dreams  False          7.7
# 22                                            Star Wars  False          8.1
# 23                                   Once Were Warriors  False          7.6
# 24                               Leon: The Professional  False          8.2
# 25                                         Pulp Fiction  False          8.3
# 26                                    Three Colors: Red  False          7.8
# 27                                   Three Colors: Blue  False          7.7
# 28                             The Shawshank Redemption  False          8.5
# 29                                              To Live  False          7.7
# ...                                                 ...    ...          ...
# 4307                                             24Ã—36  False          8.1
# 4308  Rick and Morty: State of Georgia Vs. Denver Fe...  False          8.7
# 4309                                             Zero 3  False          8.7
# 4310                                      A German Life  False          7.5
# 4311                                           Geronimo  False          7.7
# 4312                                             Baasha  False          7.8
# 4313                                      Der Herr Karl  False         10.0
# 4314                                              LA 92  False          8.8
# 4315                                      Descendants 2  False          7.5
# 4316                      Chris Gethard: Career Suicide  False          7.5
# 4317                                                Lou  False          8.5
# 4318                               The Spider Labyrinth  False          7.6
# 4319                                             Hi Way  False          7.5
# 4320                                 Les fourmis rouges  False          7.5
# 4321                                  Year of the Devil  False          7.7
# 4322                                  Enlightened blood  False          8.3
# 4323                                   Squint Your Eyes  False          8.0
# 4324                                               Love  False          7.6
# 4325                   Leslie Caron: The Reluctant Star  False          8.0
# 4326                                    Bye Bye Germany  False          8.7
# 4327                                   Twelve Angry Men  False          8.5
# 4328               A History of Horror with Mark Gatiss  False          9.0
# 4329                  The Many Faces of Christopher Lee  False         10.0
# 4330              LEGO DC Super Hero Girls: Brain Drain  False         10.0
# 4331                                          Black Sun  False          8.3
# 4332                  Thick Lashes of Lauri MÃ¤ntyvaara  False          8.0
# 4333                                        Dyketactics  False          8.0
# 4334                                     In a Heartbeat  False          8.3
# 4335                       The Man with the Rubber Head  False          7.6
# 4336                                Century of Birthing  False          9.0
#
#      vote_count
# 0          5415
# 1          1886
# 2          1343
# 3           308
# 4          5915
# 5          3334
# 6            11
# 7           181
# 8            20
# 9             6
# 10          695
# 11         3404
# 12         2632
# 13            2
# 14          249
# 15           71
# 16            1
# 17          119
# 18           45
# 19          984
# 20           76
# 21           91
# 22         6778
# 23          106
# 24         4293
# 25         8670
# 26          246
# 27          311
# 28         8358
# 29           62
# ...         ...
# 4307          7
# 4308         10
# 4309          3
# 4310          2
# 4311          9
# 4312         14
# 4313          1
# 4314          3
# 4315        171
# 4316          4
# 4317         17
# 4318          7
# 4319          2
# 4320          1
# 4321          6
# 4322          2
# 4323          2
# 4324          5
# 4325          1
# 4326          3
# 4327          4
# 4328          3
# 4329          1
# 4330          2
# 4331          3
# 4332          1
# 4333          1
# 4334        146
# 4335         29
# 4336          3
#
# [4337 rows x 24 columns]

# %% [markdown]
# ## 2. Combine Wikipedia and IMDb plot summaries
# <p>The dataset we imported currently contains two columns titled <code>wiki_plot</code> and <code>imdb_plot</code>. They are the plot found for the movies on Wikipedia and IMDb, respectively. The text in the two columns is similar, however, they are often written in different tones and thus provide context on a movie in a different manner of linguistic expression. Further, sometimes the text in one column may mention a feature of the plot that is not present in the other column. For example, consider the following plot extracts from <em>The Godfather</em>:</p>
# <ul>
# <li>Wikipedia: "On the day of his only daughter's wedding, Vito Corleone"</li>
# <li>IMDb: "In late summer 1945, guests are gathered for the wedding reception of Don Vito Corleone's daughter Connie"</li>
# </ul>
# <p>While the Wikipedia plot only mentions it is the day of the daughter's wedding, the IMDb plot also mentions the year of the scene and the name of the daughter. </p>
# <p>Let's combine both the columns to avoid the overheads in computation associated with extra columns to process.</p>

# %%
# Combine wiki_plot and imdb_plot into a single column
movies_df["plot"] = movies_df["overview"].astype(str)

# Inspect the new DataFrame
movies_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  60000000
# 2  False                                                NaN  52000000
# 3  False                                                NaN  18000000
# 4  False                                                NaN  33000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 3  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...
# 4  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
# 1                                   NaN  949  tt0113277                en
# 2                                   NaN  524  tt0112641                en
# 3                                   NaN  902  tt0112682                fr
# 4            http://www.sevenmovie.com/  807  tt0114369                en
#
#                 original_title  \
# 0                    Toy Story
# 1                         Heat
# 2                       Casino
# 3  La CitÃ© des Enfants Perdus
# 4                        Se7en
#
#                                             overview  ...    revenue runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  373554033    81.0
# 1  Obsessive master thief, Neil McCauley leads a ...  ...  187436818   170.0
# 2  The life of the gambling paradise â€“ Las Vega...  ...  116112375   178.0
# 3  A scientist in a surrealist society kidnaps ch...  ...    1738611   108.0
# 4  Two homicide detectives are on a desperate hun...  ...  327311859   127.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'cn', 'name': 'å¹¿å·žè¯ / å»£å...  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                      tagline                      title  \
# 0                                        NaN                  Toy Story
# 1                   A Los Angeles Crime Saga                       Heat
# 2           No one stays at the top forever.                     Casino
# 3  Where happily ever after is just a dream.  The City of Lost Children
# 4      Seven deadly sins. Seven ways to die.                      Se7en
#
#    video vote_average vote_count  \
# 0  False          7.7       5415
# 1  False          7.7       1886
# 2  False          7.8       1343
# 3  False          7.6        308
# 4  False          8.1       5915
#
#                                                 plot
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  Obsessive master thief, Neil McCauley leads a ...
# 2  The life of the gambling paradise â€“ Las Vega...
# 3  A scientist in a surrealist society kidnaps ch...
# 4  Two homicide detectives are on a desperate hun...
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 3. Tokenization
# <p>Tokenization is the process  by which we break down articles into individual sentences or words, as needed. Besides the tokenization method provided by NLTK, we might have to perform additional filtration to remove tokens which are entirely numeric values or punctuation.</p>
# <p>While a program may fail to build context from "While waiting at a bus stop in 1981" (<em>Forrest Gump</em>), because this string would not match in any dictionary, it is possible to build context from the words "while", "waiting" or "bus" because they are present in the English dictionary. </p>
# <p>Let us perform tokenization on a small extract from <em>The Godfather</em>.</p>

# %%
# Remove tokens that do not contain any letters from words_tokenized
import re

# %% [markdown]
# ## 4. Stemming
# <p>Stemming is the process by which we bring down a word from its different forms to the root word. This helps us establish meaning to different forms of the same words without having to deal with each form separately. For example, the words 'fishing', 'fished', and 'fisher' all get stemmed to the word 'fish'.</p>
# <p>Consider the following sentences:</p>
# <ul>
# <li>"Young William Wallace witnesses the treachery of Longshanks" ~ <em>Gladiator</em></li>
# <li>"escapes to the city walls only to witness Cicero's death" ~ <em>Braveheart</em></li>
# </ul>
# <p>Instead of building separate dictionary entries for both witnesses and witness, which mean the same thing outside of quantity, stemming them reduces them to 'wit'.</p>
# <p>There are different algorithms available for stemming such as the Porter Stemmer, Snowball Stemmer, etc. We shall use the Snowball Stemmer.</p>

# %%
# Import the SnowballStemmer to perform stemming
# ... YOUR CODE FOR TASK 4 ...
from nltk.stem.snowball import SnowballStemmer

# Create an English language SnowballStemmer object
stemmer = SnowballStemmer("english")

# %% [markdown]
# ## 5. Club together Tokenize & Stem
# <p>We are now able to tokenize and stem sentences. But we may have to use the two functions repeatedly one after the other to handle a large amount of data, hence we can think of wrapping them in a function and passing the text to be tokenized and stemmed as the function argument. Then we can pass the new wrapping function, which shall perform both tokenizing and stemming instead of just tokenizing, as the tokenizer argument while creating the TF-IDF vector of the text.  </p>
# <p>What difference does it make though? Consider the sentence from the plot of <em>The Godfather</em>: "Today (May 19, 2016) is his only daughter's wedding." If we do a 'tokenize-only' for this sentence, we have the following result:</p>
# <blockquote>
#   <p>'today', 'may', 'is', 'his', 'only', 'daughter', "'s", 'wedding'</p>
# </blockquote>
# <p>But when we do a 'tokenize-and-stem' operation we get:</p>
# <blockquote>
#   <p>'today', 'may', 'is', 'his', 'onli', 'daughter', "'s", 'wed'</p>
# </blockquote>
# <p>All the words are in their root form, which will lead to a better establishment of meaning as some of the non-root forms may not be present in the NLTK training corpus.</p>

# %%
# Define a function to perform both stemming and tokenization
def tokenize_and_stem(text):
    
    # Tokenize by sentence, then by word
    tokens = [y for x in nltk.sent_tokenize(text) for y in nltk.word_tokenize(x)]
    
    # Filter out raw tokens to remove noise
    filtered_tokens = [token for token in tokens if re.search('[a-zA-Z]', token)]
    
    # Stem the filtered_tokens
    stems = [stemmer.stem(word) for word in filtered_tokens]
    
    return stems

# %% [markdown]
# ## 6. Create TfidfVectorizer
# <p>Computers do not <em>understand</em> text. These are machines only capable of understanding numbers and performing numerical computation. Hence, we must convert our textual plot summaries to numbers for the computer to be able to extract meaning from them. One simple method of doing this would be to count all the occurrences of each word in the entire vocabulary and return the counts in a vector. Enter <code>CountVectorizer</code>.</p>
# <p>Consider the word 'the'. It appears quite frequently in almost all movie plots and will have a high count in each case. But obviously, it isn't the theme of all the movies! <a href="https://campus.datacamp.com/courses/natural-language-processing-fundamentals-in-python/simple-topic-identification?ex=11">Term Frequency-Inverse Document Frequency</a> (TF-IDF) is one method which overcomes the shortcomings of <code>CountVectorizer</code>. The Term Frequency of a word is the measure of how often it appears in a document, while the Inverse Document Frequency is the parameter which reduces the importance of a word if it frequently appears in several documents.</p>
# <p>For example, when we apply the TF-IDF on the first 3 sentences from the plot of <em>The Wizard of Oz</em>, we are told that the most important word there is 'Toto', the pet dog of the lead character. This is because the movie begins with 'Toto' biting someone due to which the journey of Oz begins!</p>
# <p>In simplest terms, TF-IDF recognizes words which are unique and important to any given document. Let's create one for our purposes.</p>

# %%
# Import TfidfVectorizer to create TF-IDF vectors
# ... YOUR CODE FOR TASK 6 ...

from sklearn.feature_extraction.text import TfidfVectorizer

# Instantiate TfidfVectorizer object with stopwords and tokenizer
# parameters for efficient processing of text
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=2000000,
                                 min_df=0.2, stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem,
                                 ngram_range=(1,3))

# %% [markdown]
# ## 7. Fit transform TfidfVectorizer
# <p>Once we create a TF-IDF Vectorizer, we must fit the text to it and then transform the text to produce the corresponding numeric form of the data which the computer will be able to understand and derive meaning from. To do this, we use the <code>fit_transform()</code> method of the <code>TfidfVectorizer</code> object. </p>
# <p>If we observe the <code>TfidfVectorizer</code> object we created, we come across a parameter stopwords. 'stopwords' are those words in a given text which do not contribute considerably towards the meaning of the sentence and are generally grammatical filler words. For example, in the sentence 'Dorothy Gale lives with her dog Toto on the farm of her Aunt Em and Uncle Henry', we could drop the words 'her' and 'the', and still have a similar overall meaning to the sentence. Thus, 'her' and 'the' are stopwords and can be conveniently dropped from the sentence. </p>
# <p>On setting the stopwords to 'english', we direct the vectorizer to drop all stopwords from a pre-defined list of English language stopwords present in the nltk module. Another parameter, <code>ngram_range</code>, defines the length of the ngrams to be formed while vectorizing the text.</p>

# %%
# Fit and transform the tfidf_vectorizer with the "plot" of each movie
# to create a vector representation of the plot summaries
tfidf_matrix = tfidf_vectorizer.fit_transform([x for x in movies_df["plot"]])

print(tfidf_matrix.shape)
# Out:
# C:\Users\hjp28\anaconda\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# (4337, 1)

# %% [markdown]
# ## 8. Import KMeans and create clusters
# <p>To determine how closely one movie is related to the other by the help of unsupervised learning, we can use clustering techniques. Clustering is the method of grouping together a number of items such that they exhibit similar properties. According to the measure of similarity desired, a given sample of items can have one or more clusters. </p>
# <p>A good basis of clustering in our dataset could be the genre of the movies. Say we could have a cluster '0' which holds movies of the 'Drama' genre. We would expect movies like <em>Chinatown</em> or <em>Psycho</em> to belong to this cluster. Similarly, the cluster '1' in this project holds movies which belong to the 'Adventure' genre (<em>Lawrence of Arabia</em> and the <em>Raiders of the Lost Ark</em>, for example).</p>
# <p>K-means is an algorithm which helps us to implement clustering in Python. The name derives from its method of implementation: the given sample is divided into <b><i>K</i></b> clusters where each cluster is denoted by the <b><i>mean</i></b> of all the items lying in that cluster. </p>
# <p>We get the following distribution for the clusters:</p>
# <p><img src="https://assets.datacamp.com/production/project_648/img/bar_clusters.png" alt="bar graph of clusters"></p>

# %%
# Import k-means to perform clusters
from sklearn.cluster import KMeans

# Create a KMeans object with 5 clusters and save as km
km = KMeans(n_clusters=5)

# Fit the k-means object with tfidf_matrix
km.fit(tfidf_matrix)

clusters = km.labels_.tolist()

# Create a column cluster to denote the generated cluster for each movie
movies_df["cluster"] = clusters

# Display number of films per cluster (clusters from 0 to 4)
movies_df['cluster'].value_counts()
# Out:
# C:\Users\hjp28\anaconda\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:972: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# 1    2974
# 0    1363
# Name: cluster, dtype: int64

# %% [markdown]
# ## 9. Calculate similarity distance
# <p>Consider the following two sentences from the movie <em>The Wizard of Oz</em>: </p>
# <blockquote>
#   <p>"they find in the Emerald City"</p>
#   <p>"they finally reach the Emerald City"</p>
# </blockquote>
# <p>If we put the above sentences in a <code>CountVectorizer</code>, the vocabulary produced would be "they, find, in, the, Emerald, City, finally, reach" and the vectors for each sentence would be as follows: </p>
# <blockquote>
#   <p>1, 1, 1, 1, 1, 1, 0, 0</p>
#   <p>1, 0, 0, 1, 1, 1, 1, 1</p>
# </blockquote>
# <p>When we calculate the cosine angle formed between the vectors represented by the above, we get a score of 0.667. This means the above sentences are very closely related. <em>Similarity distance</em> is 1 - <a href="https://en.wikipedia.org/wiki/Cosine_similarity">cosine similarity angle</a>. This follows from that if the vectors are similar, the cosine of their angle would be 1 and hence, the distance between then would be 1 - 1 = 0.</p>
# <p>Let's calculate the similarity distance for all of our movies.</p>

# %%
# Import cosine_similarity to calculate similarity of movie plots
from sklearn.metrics.pairwise import cosine_similarity

# Calculate the similarity distance
similarity_distance = 1 - cosine_similarity(tfidf_matrix)

# %% [markdown]
# ## 10. Import Matplotlib, Linkage, and Dendrograms
# <p>We shall now create a tree-like diagram (called a dendrogram) of the movie titles to help us understand the level of similarity between them visually. Dendrograms help visualize the results of hierarchical clustering, which is an alternative to k-means clustering. Two pairs of movies at the same level of hierarchical clustering are expected to have similar strength of similarity between the corresponding pairs of movies. For example, the movie <em>Fargo</em> would be as similar to <em>North By Northwest</em> as the movie <em>Platoon</em> is to <em>Saving Private Ryan</em>, given both the pairs exhibit the same level of the hierarchy.</p>
# <p>Let's import the modules we'll need to create our dendrogram.</p>

# %%
# Import matplotlib.pyplot for plotting graphs
# ... YOUR CODE FOR TASK 10 ...

import matplotlib.pyplot as plt

# Configure matplotlib to display the output inline
# %matplotlib inline

# Import modules necessary to plot dendrogram
# ... YOUR CODE FOR TASK 10 ...

from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import linkage

# %% [markdown]
# ## 11. Create merging and plot dendrogram
# <p>We shall plot a dendrogram of the movies whose similarity measure will be given by the similarity distance we previously calculated. The lower the similarity distance between any two movies, the lower their linkage will make an intercept on the y-axis. For instance, the lowest dendrogram linkage we shall discover will be between the movies, <em>It's a Wonderful Life</em> and <em>A Place in the Sun</em>. This indicates that the movies are very similar to each other in their plots.</p>

# %%
# Create mergings matrix 
mergings = linkage(similarity_distance, method='complete')

# Plot the dendrogram, using title as label column
dendrogram_ = dendrogram(mergings,
               labels=[x for x in movies_df["title"]],
               leaf_rotation=90,
               leaf_font_size=16,
)

# Adjust the plot
fig = plt.gcf()
_ = [lbl.set_color('r') for lbl in plt.gca().get_xmajorticklabels()]
fig.set_size_inches(108, 21)

# Show the plotted dendrogram
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-32-21860de1f369> in <module>
#       6                labels=[x for x in movies_df["title"]],
#       7                leaf_rotation=90,
# ----> 8                leaf_font_size=16,
#       9 )
#      10
#
# ~\anaconda\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in dendrogram(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, no_plot, no_labels, leaf_font_size, leaf_rotation, leaf_label_func, show_contracted, link_color_func, ax, above_threshold_color)
#    3393         contraction_marks=contraction_marks,
#    3394         link_color_func=link_color_func,
# -> 3395         above_threshold_color=above_threshold_color)
#    3396
#    3397     if not no_plot:
#
# ~\anaconda\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in _dendrogram_calculate_info(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, i, iv, ivl, n, icoord_list, dcoord_list, lvs, mhr, current_color, color_list, currently_below_threshold, leaf_label_func, level, contraction_marks, link_color_func, above_threshold_color)
#    3679             level=level + 1, contraction_marks=contraction_marks,
#    3680             link_color_func=link_color_func,
# -> 3681             above_threshold_color=above_threshold_color)
#    3682
#    3683     max_dist = max(uamd, ubmd, h)
#
# ... last 1 frames repeated, from the frame below ...
#
# ~\anaconda\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in _dendrogram_calculate_info(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, i, iv, ivl, n, icoord_list, dcoord_list, lvs, mhr, current_color, color_list, currently_below_threshold, leaf_label_func, level, contraction_marks, link_color_func, above_threshold_color)
#    3679             level=level + 1, contraction_marks=contraction_marks,
#    3680             link_color_func=link_color_func,
# -> 3681             above_threshold_color=above_threshold_color)
#    3682
#    3683     max_dist = max(uamd, ubmd, h)
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# ## 12. Which movies are most similar?
# <p>We can now determine the similarity between movies based on their plots! To wrap up, let's answer one final question: which movie is most similar to the movie <em>Braveheart</em>?</p>

# %%
# Answer the question 
ans = "Gladiator"
print(ans)
# Out:
# Gladiator
