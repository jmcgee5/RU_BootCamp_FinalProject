# %% [markdown]
# ## 1. Import and observe dataset
# <p>We all love watching movies! There are some movies we like, some we don't. Most people have a preference for movies of a similar genre. Some of us love watching action movies, while some of us like watching horror. Some of us like watching movies that have ninjas in them, while some of us like watching superheroes.</p>
# <p>Movies within a genre often share common base parameters. Consider the following two movies:</p>
# <p><img style="margin:5px 20px 5px 1px; height: 250px; display: inline-block;" alt="2001: A Space Odyssey" src="https://assets.datacamp.com/production/project_648/img/movie1.jpg">
# <img style="margin:5px 20px 5px 1px; height: 250px; display: inline-block;" alt="Close Encounters of the Third Kind" src="https://assets.datacamp.com/production/project_648/img/movie2.jpg"></p>
# <p>Both movies, <em>2001: A Space Odyssey</em> and <em>Close Encounters of the Third Kind</em>, are movies based on aliens coming to Earth. I've seen both, and they indeed share many similarities. We could conclude that both of these fall into the same genre of movies based on intuition, but that's no fun in a data science context. In this notebook, we will quantify the similarity of movies based on their plot summaries available on IMDb and Wikipedia, then separate them into groups, also known as clusters. We'll create a dendrogram to represent how closely the movies are related to each other.</p>
# <p>Let's start by importing the dataset and observing the data provided.</p>

# %%
# Import modules
import numpy as np
import pandas as pd
import nltk

# Set seed for reproducibility
np.random.seed(5)

# Read in IMDb and Wikipedia movie data (both in same file)
movies_df = pd.read_csv("datasets/movies_ratings.csv")

print("Number of movies loaded: %s " % (len(movies_df)))

# Display the data
movies_df
# Out:
# Number of movies loaded: 754
#      adult                              belongs_to_collection     budget  \
# 0    False  {'id': 10194, 'name': 'Toy Story Collection', ...   30000000
# 1    False                                                NaN   60000000
# 2    False                                                NaN   52000000
# 3    False                                                NaN   33000000
# 4    False                                                NaN    6000000
# 5    False                                                NaN   72000000
# 6    False                                                NaN    1300000
# 7    False                                                NaN          0
# 8    False                                                NaN          0
# 9    False  {'id': 123800, 'name': 'Before... Collection',...    2500000
# 10   False                                                NaN     700000
# 11   False  {'id': 10, 'name': 'Star Wars Collection', 'po...   11000000
# 12   False  {'id': 300546, 'name': 'Once were Warriors Col...          0
# 13   False                                                NaN    8000000
# 14   False                                                NaN   25000000
# 15   False                                                NaN   11000000
# 16   False                                                NaN   55000000
# 17   False  {'id': 94032, 'name': 'The Lion King Collectio...   45000000
# 18   False                                                NaN   30000000
# 19   False                                                NaN          0
# 20   False                                                NaN   13000000
# 21   False  {'id': 328, 'name': 'Jurassic Park Collection'...   63000000
# 22   False                                                NaN          0
# 23   False                                                NaN   26000000
# 24   False                                                NaN   11500000
# 25   False                                                NaN   22000000
# 26   False  {'id': 422837, 'name': 'Blade Runner Collectio...   28000000
# 27   False                                                NaN   18000000
# 28   False                                                NaN   12500000
# 29   False  {'id': 528, 'name': 'The Terminator Collection...  100000000
# ..     ...                                                ...        ...
# 724  False                                                NaN          0
# 725  False                                                NaN          0
# 726  False                                                NaN          0
# 727  False                                                NaN          0
# 728  False                                                NaN          0
# 729  False                                                NaN          0
# 730  False                                                NaN          0
# 731  False                                                NaN          0
# 732  False                                                NaN    7000000
# 733  False                                                NaN  125000000
# 734  False                                                NaN          0
# 735  False                                                NaN          0
# 736  False                                                NaN          0
# 737  False                                                NaN   10000000
# 738  False                                                NaN          0
# 739  False                                                NaN          0
# 740  False                                                NaN          0
# 741  False                                                NaN          0
# 742  False                                                NaN   50000000
# 743  False                                                NaN          0
# 744  False                                                NaN          0
# 745  False                                                NaN          0
# 746  False                                                NaN    4000000
# 747  False                                                NaN          0
# 748  False                                                NaN          0
# 749  False                                                NaN          0
# 750  False                                                NaN  100000000
# 751  False                                                NaN     273428
# 752  False  {'id': 466463, 'name': 'Descendants Collection...          0
# 753  False                                                NaN          0
#
#                                                 genres  \
# 0    [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 3    [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 4    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 5    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 6    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 7                  [{'id': 99, 'name': 'Documentary'}]
# 8    [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 9    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 10                 [{'id': 99, 'name': 'Documentary'}]
# 11   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 12                       [{'id': 18, 'name': 'Drama'}]
# 13   [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 14   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 15   [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 16   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 17   [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 18   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 19   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 20                       [{'id': 18, 'name': 'Drama'}]
# 21   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 22   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 23                       [{'id': 18, 'name': 'Drama'}]
# 24   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 25   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 26   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 27   [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...
# 28   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 29   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ..                                                 ...
# 724  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 725  [{'id': 10751, 'name': 'Family'}, {'id': 18, '...
# 726                   [{'id': 10402, 'name': 'Music'}]
# 727  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 728  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 729                     [{'id': 35, 'name': 'Comedy'}]
# 730                     [{'id': 35, 'name': 'Comedy'}]
# 731  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 732                      [{'id': 18, 'name': 'Drama'}]
# 733  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 734                     [{'id': 35, 'name': 'Comedy'}]
# 735                      [{'id': 18, 'name': 'Drama'}]
# 736  [{'id': 10770, 'name': 'TV Movie'}, {'id': 53,...
# 737  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 738                [{'id': 99, 'name': 'Documentary'}]
# 739                [{'id': 99, 'name': 'Documentary'}]
# 740                                                 []
# 741  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
# 742  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 743                [{'id': 99, 'name': 'Documentary'}]
# 744                                                 []
# 745  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 746  [{'id': 10770, 'name': 'TV Movie'}, {'id': 35,...
# 747                      [{'id': 18, 'name': 'Drama'}]
# 748  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 749  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 750  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 751                [{'id': 99, 'name': 'Documentary'}]
# 752  [{'id': 10770, 'name': 'TV Movie'}, {'id': 107...
# 753  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#
#                                               homepage      id    imdb_id  \
# 0                 http://toystory.disney.com/toy-story     862  tt0114709
# 1                                                  NaN     949  tt0113277
# 2                                                  NaN     524  tt0112641
# 3                           http://www.sevenmovie.com/     807  tt0114369
# 4    http://www.mgm.com/#/our-titles/2083/The-Usual...     629  tt0114814
# 5                                                  NaN     197  tt0112573
# 6                                                  NaN     103  tt0075314
# 7                                                  NaN   26564  tt0109508
# 8                                                  NaN   19155  tt0110882
# 9                                                  NaN      76  tt0112471
# 10                                                 NaN   14275  tt0110057
# 11   http://www.starwars.com/films/star-wars-episod...      11  tt0076759
# 12                                                 NaN     527  tt0110729
# 13                                                 NaN     680  tt0110912
# 14                                                 NaN     278  tt0111161
# 15                                                 NaN    1587  tt0108550
# 16                                                 NaN      13  tt0109830
# 17              http://movies.disney.com/the-lion-king    8587  tt0110357
# 18                                                 NaN    6075  tt0106519
# 19                                                 NaN   13815  tt0109842
# 20                                                 NaN    7984  tt0107207
# 21                        http://www.jurassicpark.com/     329  tt0107290
# 22                                                 NaN   21450  tt0107653
# 23                                                 NaN    9800  tt0107818
# 24                                                 NaN    1245  tt0107943
# 25                      http://www.schindlerslist.com/     424  tt0108052
# 26              http://www.warnerbros.com/blade-runner      78  tt0083658
# 27                                                 NaN    9479  tt0107688
# 28                                                 NaN     319  tt0108399
# 29                                                 NaN     280  tt0103064
# ..                                                 ...     ...        ...
# 724                         http://thebigsickmovie.com  416477  tt5462602
# 725  http://www.hm.com/us/magazine/culture/h-m-insi...  428074  tt6282412
# 726                                                NaN  394269  tt5662106
# 727                                                NaN    4369  tt0231844
# 728                                                NaN  371504  tt4258440
# 729                                                NaN  444705  tt6648926
# 730                                                NaN  444706  tt6649108
# 731                                                NaN   32536  tt0234588
# 732              http://www.foxsearchlight.com/gifted/  400928  tt4481414
# 733                http://www.hbo.com/band-of-brothers  331214  tt0185906
# 734                                                NaN  449674  tt6736782
# 735                                                NaN  283591  tt3344694
# 736                                                NaN  284457  tt5334704
# 737        http://www.focusfeatures.com/thebookofhenry  382614  tt4572792
# 738           http://www.bbc.co.uk/programmes/p02544td  420714  tt5491994
# 739                     https://www.iamheathledger.com  450945  tt6739646
# 740                                                NaN  409926  tt0081846
# 741                                                NaN   25771  tt0069090
# 742             https://www.netflix.com/title/80091936  387426  tt3967856
# 743                     http://www.lifecyclesfilm.com/   51299  tt1828232
# 744                                                NaN   80617  tt0383126
# 745                                                NaN  107170  tt2386231
# 746                                                NaN  447061  tt6582384
# 747                                                NaN  340027  tt3704700
# 748                                                NaN   67409  tt0045709
# 749                                                NaN  374430  tt3973198
# 750                       http://www.dunkirkmovie.com/  374720  tt5013056
# 751                  http://www.whatthehealthfilm.com/  415086  tt5541848
# 752                                                NaN  417320  tt5117876
# 753                                                NaN  455661  tt6969946
#
#     original_language                                     original_title  \
# 0                  en                                          Toy Story
# 1                  en                                               Heat
# 2                  en                                             Casino
# 3                  en                                              Se7en
# 4                  en                                 The Usual Suspects
# 5                  en                                         Braveheart
# 6                  en                                        Taxi Driver
# 7                  en                                              Crumb
# 8                  en                                    Before the Rain
# 9                  en                                     Before Sunrise
# 10                 en                                        Hoop Dreams
# 11                 en                                          Star Wars
# 12                 en                                 Once Were Warriors
# 13                 en                                       Pulp Fiction
# 14                 en                           The Shawshank Redemption
# 15                 en                        What's Eating Gilbert Grape
# 16                 en                                       Forrest Gump
# 17                 en                                      The Lion King
# 18                 en                                      Carlito's Way
# 19                 en                                              Fresh
# 20                 en                          In the Name of the Father
# 21                 en                                      Jurassic Park
# 22                 en                                              Naked
# 23                 en                                       Philadelphia
# 24                 en                             The Remains of the Day
# 25                 en                                   Schindler's List
# 26                 en                                       Blade Runner
# 27                 en                     The Nightmare Before Christmas
# 28                 en                                       True Romance
# 29                 en                         Terminator 2: Judgment Day
# ..                ...                                                ...
# 724                en                                       The Big Sick
# 725                en                                      Come Together
# 726                en                                           Lemonade
# 727                en                         Juste une question d'amour
# 728                en                                              River
# 729                en                    Dave Chappelle: The Age of Spin
# 730                en         Dave Chappelle: Deep in the Heart of Texas
# 731                en                                           Rejected
# 732                en                                             Gifted
# 733                en                                   Band of Brothers
# 734                en                                    Louis C.K. 2017
# 735                en                               The Secret Scripture
# 736                en  Twin Peaks: Fire Walk with Me - The Missing Pi...
# 737                en                                  The Book of Henry
# 738                en                                    Planet Earth II
# 739                en                                  I Am Heath Ledger
# 740                en                                             Cosmos
# 741                en                        Pink Floyd: Live at Pompeii
# 742                en                                               Okja
# 743                en                                        Life Cycles
# 744                en                        Mythbusters Holiday Special
# 745                en                                 Ghost Recon: Alpha
# 746                en                              Red Nose Day Actually
# 747                en                                      Brain on Fire
# 748                en                 Duck Dodgers in the 24Â½th Century
# 749                en                      Black Mirror: White Christmas
# 750                en                                            Dunkirk
# 751                en                                    What the Health
# 752                en                                      Descendants 2
# 753                en                                     In a Heartbeat
#
#                                               overview  ...  release_date  \
# 0    Led by Woody, Andy's toys live happily in his ...  ...    10/30/1995
# 1    Obsessive master thief, Neil McCauley leads a ...  ...    12/15/1995
# 2    The life of the gambling paradise â€“ Las Vega...  ...    11/22/1995
# 3    Two homicide detectives are on a desperate hun...  ...     9/22/1995
# 4    Held in an L.A. interrogation room, Verbal Kin...  ...     7/19/1995
# 5    Enraged at the slaughter of Murron, his new br...  ...     5/24/1995
# 6    A mentally unstable Vietnam War veteran works ...  ...      2/7/1976
# 7    This movie chronicles the life and times of R....  ...     9/10/1994
# 8    The circularity of violence seen in a story th...  ...      6/9/1994
# 9    A dialogue marathon of a film, this fairytale ...  ...     1/27/1995
# 10   This documentary follows two inner-city Chicag...  ...     9/12/1994
# 11   Princess Leia is captured and held hostage by ...  ...     5/25/1977
# 12   A drama about a Maori family lving in Auckland...  ...      9/2/1994
# 13   A burger-loving hit man, his philosophical par...  ...     9/10/1994
# 14   Framed in the 1940s for the double murder of h...  ...     9/23/1994
# 15   Gilbert has to care for his brother Arnie and ...  ...    12/17/1993
# 16   A man with a low IQ has accomplished great thi...  ...      7/6/1994
# 17   A young lion cub named Simba can't wait to be ...  ...     6/23/1994
# 18   A Puerto-Rican ex-con, just released from pris...  ...    11/10/1993
# 19   Michael is a 12-year-old drug pusher who lives...  ...     8/24/1994
# 20   A small time thief from Belfast, Gerry Conlon,...  ...    12/12/1993
# 21   A wealthy entrepreneur secretly creates a them...  ...     6/11/1993
# 22   Johnny flees Manchester for London, to avoid a...  ...     9/14/1993
# 23   No one would take his case until one man was w...  ...    12/22/1993
# 24   A rule bound head butler's world of manners an...  ...     11/5/1993
# 25   The true story of how businessman Oskar Schind...  ...    11/29/1993
# 26   In the smog-choked dystopian Los Angeles of 20...  ...     6/25/1982
# 27   Tired of scaring humans every October 31 with ...  ...     10/9/1993
# 28   Clarence marries hooker Alabama, steals cocain...  ...      9/9/1993
# 29   Nearly 10 years have passed since Sarah Connor...  ...      7/1/1991
# ..                                                 ...  ...           ...
# 724  Pakistan-born comedian Kumail Nanjiani and gra...  ...     6/23/2017
# 725  A train is delayed on Christmas day due to a s...  ...    11/27/2016
# 726  The second "visual album" (a collection of sho...  ...     4/23/2016
# 727  After his gay cousin dies from hepatitis, youn...  ...      1/1/2000
# 728  John River, a brilliant police officer whose g...  ...    10/13/2015
# 729  Comedy icon Dave Chappelle makes his triumphan...  ...     3/21/2017
# 730  Comedy icon Dave Chappelle makes his triumphan...  ...     3/21/2017
# 731  An animator's commissioned works, rejected bec...  ...     7/25/2000
# 732  Frank, a single man raising his child prodigy ...  ...     4/12/2017
# 733  Drawn from interviews with survivors of Easy C...  ...      9/9/2001
# 734  Louis C.K. muses on religion, eternal love, gi...  ...      4/4/2017
# 735  The hidden memoir of an elderly woman confined...  ...     11/4/2016
# 736  The long-awaited missing pieces from the origi...  ...     7/29/2014
# 737  Naomi Watts stars as Susan, a single mother of...  ...     6/16/2017
# 738  David Attenborough presents a documentary seri...  ...     11/6/2016
# 739  The life and career of an actor, artist, and i...  ...     4/23/2017
# 740  Astronomer Dr. Carl Sagan is host and narrator...  ...           NaN
# 741  Stylish film of the British progressive rock b...  ...     8/31/1972
# 742  A young girl named Mija risks everything to pr...  ...     5/19/2017
# 743  Life Cycles tells a spectacular story of the b...  ...     10/2/2010
# 744  Holiday Themed Myths. Can the Mythbusters real...  ...     12/6/2006
# 745  Ghost Recon: Alpha sees a team led by Ghost Le...  ...      5/3/2012
# 746  Fourteen years after the events of the first f...  ...     3/24/2017
# 747  A look at a young woman's rapid descent into i...  ...     2/22/2017
# 748  Space hero Daffy battles Marvin the Martian fo...  ...     7/25/1953
# 749  This feature-length special consists of three ...  ...    12/16/2014
# 750  The miraculous evacuation of Allied soldiers f...  ...     7/19/2017
# 751  What the Health is a ground breaking feature l...  ...     3/16/2017
# 752  When the pressure to be royal becomes too much...  ...     7/21/2017
# 753  A closeted boy runs the risk of being outed by...  ...      6/1/2017
#
#        revenue runtime                                   spoken_languages  \
# 0    373554033      81           [{'iso_639_1': 'en', 'name': 'English'}]
# 1    187436818     170  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2    116112375     178           [{'iso_639_1': 'en', 'name': 'English'}]
# 3    327311859     127           [{'iso_639_1': 'en', 'name': 'English'}]
# 4     23341568     106  [{'iso_639_1': 'es', 'name': 'EspaÃ±ol'}, {'is...
# 5    210000000     177  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6     28262574     114  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 7      3174695     119           [{'iso_639_1': 'en', 'name': 'English'}]
# 8       763847     113  [{'iso_639_1': 'sq', 'name': 'shqip'}, {'iso_6...
# 9      5535405     105  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 10     7830611     171           [{'iso_639_1': 'en', 'name': 'English'}]
# 11   775398007     121           [{'iso_639_1': 'en', 'name': 'English'}]
# 12     2201126      99  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 13   213928762     154  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 14    28341469     142           [{'iso_639_1': 'en', 'name': 'English'}]
# 15    10032765     118           [{'iso_639_1': 'en', 'name': 'English'}]
# 16   677945399     142           [{'iso_639_1': 'en', 'name': 'English'}]
# 17   788241776      89           [{'iso_639_1': 'en', 'name': 'English'}]
# 18    36516012     144  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 19           0     114           [{'iso_639_1': 'en', 'name': 'English'}]
# 20    65796862     133           [{'iso_639_1': 'en', 'name': 'English'}]
# 21   920100000     127  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 22           0     131           [{'iso_639_1': 'en', 'name': 'English'}]
# 23   206678440     125           [{'iso_639_1': 'en', 'name': 'English'}]
# 24    23237911     134           [{'iso_639_1': 'en', 'name': 'English'}]
# 25   321365567     195  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 26    33139618     117  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 27    75634409      76           [{'iso_639_1': 'en', 'name': 'English'}]
# 28    12281551     120  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 29   520000000     137  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ..         ...     ...                                                ...
# 724   52620184     120  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 725          0       4           [{'iso_639_1': 'en', 'name': 'English'}]
# 726          0      65           [{'iso_639_1': 'en', 'name': 'English'}]
# 727          0      88         [{'iso_639_1': 'fr', 'name': 'FranÃ§ais'}]
# 728          0     349           [{'iso_639_1': 'en', 'name': 'English'}]
# 729          0      67           [{'iso_639_1': 'en', 'name': 'English'}]
# 730          0      66           [{'iso_639_1': 'en', 'name': 'English'}]
# 731          0       9  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 732   37461045     101           [{'iso_639_1': 'en', 'name': 'English'}]
# 733          0     705  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 734          0      74           [{'iso_639_1': 'en', 'name': 'English'}]
# 735     152761     108           [{'iso_639_1': 'en', 'name': 'English'}]
# 736          0      91           [{'iso_639_1': 'en', 'name': 'English'}]
# 737    4219536     105           [{'iso_639_1': 'en', 'name': 'English'}]
# 738          0     300           [{'iso_639_1': 'en', 'name': 'English'}]
# 739          0      90           [{'iso_639_1': 'en', 'name': 'English'}]
# 740          0      60                                                 []
# 741          0      85           [{'iso_639_1': 'en', 'name': 'English'}]
# 742          0     121  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 743          0      47           [{'iso_639_1': 'en', 'name': 'English'}]
# 744          0      44                                                 []
# 745          0      24           [{'iso_639_1': 'en', 'name': 'English'}]
# 746          0      15  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 747          0      95           [{'iso_639_1': 'en', 'name': 'English'}]
# 748          0       7  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 749          0      74           [{'iso_639_1': 'en', 'name': 'English'}]
# 750  519876949     107  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 751          0      97           [{'iso_639_1': 'en', 'name': 'English'}]
# 752          0     111             [{'iso_639_1': 'da', 'name': 'Dansk'}]
# 753          0       4           [{'iso_639_1': 'en', 'name': 'English'}]
#
#        status                                            tagline  \
# 0    Released                                                NaN
# 1    Released                           A Los Angeles Crime Saga
# 2    Released                   No one stays at the top forever.
# 3    Released              Seven deadly sins. Seven ways to die.
# 4    Released       Five Criminals. One Line Up. No Coincidence.
# 5    Released         Every man dies. Not every man truly lives.
# 6    Released  On every street in every city, there's a nobod...
# 7    Released              Weird sex Â· Obsession Â· Comic books
# 8    Released  Once You Know The Faces You Will Begin To Unde...
# 9    Released  Can the greatest romance of your life last onl...
# 10   Released                       An Extraordinary True Story.
# 11   Released       A long time ago in a galaxy far, far away...
# 12   Released  A family in crisis, a life in chaos... Nothing...
# 13   Released  Just because you are a character doesn't mean ...
# 14   Released  Fear can hold you prisoner. Hope can set you f...
# 15   Released  A film about the love you find...In the last p...
# 16   Released  The world will never be the same, once you've ...
# 17   Released  Life's greatest adventure is finding your plac...
# 18   Released  He's got a good future if he can live past nex...
# 19   Released                                                NaN
# 20   Released  Falsely accused. Wrongly imprisoned. He fought...
# 21   Released       An adventure 65 million years in the making.
# 22   Released                                                NaN
# 23   Released  No one would take on his case... until one man...
# 24   Released                               Diamond in the Rough
# 25   Released    Whoever saves one life, saves the world entire.
# 26   Released    Man has made his match... now it's his problem.
# 27   Released  A ghoulish tale with wicked humor & stunning a...
# 28   Released  Stealing, Cheating, Killing. Who said romance ...
# 29   Released                             It's nothing personal.
# ..        ...                                                ...
# 724  Released                             An awkward true story.
# 725  Released                        A fashion picture in motion
# 726  Released                                                NaN
# 727  Released                                                NaN
# 728  Released                                                NaN
# 729  Released                    Live at The Hollywood Palladium
# 730  Released                         Live at Austin City Limits
# 731  Released                                                NaN
# 732  Released                                                NaN
# 733  Released                 Ordinary men. Extraordinary times.
# 734  Released                                                NaN
# 735  Released                                                NaN
# 736  Released                                                NaN
# 737  Released                         Never leave things undone.
# 738  Released                                                NaN
# 739  Released                                                NaN
# 740  Released                                                NaN
# 741  Released    More Than a Movie! An Explosive Cinema Concert!
# 742  Released                                                NaN
# 743  Released                                                NaN
# 744       NaN  They don't just tell the myths; they put them ...
# 745  Released                                                NaN
# 746  Released                                     Love Continues
# 747  Released                                                NaN
# 748  Released                                                NaN
# 749  Released                                                NaN
# 750  Released                    The event that shaped our world
# 751  Released                                                NaN
# 752  Released                                    Long live evil.
# 753  Released               The Heart Wants What The Heart Wants
#
#                                                  title  video vote_average  \
# 0                                            Toy Story  False          7.7
# 1                                                 Heat  False          7.7
# 2                                               Casino  False          7.8
# 3                                                Se7en  False          8.1
# 4                                   The Usual Suspects  False          8.1
# 5                                           Braveheart  False          7.7
# 6                                          Taxi Driver  False          8.1
# 7                                                Crumb  False          7.6
# 8                                      Before the Rain  False          7.7
# 9                                       Before Sunrise  False          7.7
# 10                                         Hoop Dreams  False          7.7
# 11                                           Star Wars  False          8.1
# 12                                  Once Were Warriors  False          7.6
# 13                                        Pulp Fiction  False          8.3
# 14                            The Shawshank Redemption  False          8.5
# 15                         What's Eating Gilbert Grape  False          7.5
# 16                                        Forrest Gump  False          8.2
# 17                                       The Lion King  False          8.0
# 18                                       Carlito's Way  False          7.7
# 19                                               Fresh  False          7.6
# 20                           In the Name of the Father  False          7.6
# 21                                       Jurassic Park  False          7.6
# 22                                               Naked  False          7.5
# 23                                        Philadelphia  False          7.6
# 24                              The Remains of the Day  False          7.5
# 25                                    Schindler's List  False          8.3
# 26                                        Blade Runner  False          7.9
# 27                      The Nightmare Before Christmas  False          7.6
# 28                                        True Romance  False          7.5
# 29                          Terminator 2: Judgment Day  False          7.7
# ..                                                 ...    ...          ...
# 724                                       The Big Sick  False          7.7
# 725                                      Come Together  False          7.6
# 726                                           Lemonade  False          8.8
# 727                            Just a Question of Love  False          7.5
# 728                                              River  False          7.9
# 729                    Dave Chappelle: The Age of Spin  False          7.6
# 730         Dave Chappelle: Deep in the Heart of Texas  False          8.0
# 731                                           Rejected  False          7.5
# 732                                             Gifted  False          7.7
# 733                                   Band of Brothers  False          8.2
# 734                                    Louis C.K. 2017  False          7.5
# 735                               The Secret Scripture  False          7.6
# 736  Twin Peaks: Fire Walk with Me - The Missing Pi...   True          7.5
# 737                                  The Book of Henry  False          7.6
# 738                                    Planet Earth II  False          9.5
# 739                                  I Am Heath Ledger  False          7.5
# 740                                             Cosmos  False          9.1
# 741                        Pink Floyd: Live at Pompeii  False          8.3
# 742                                               Okja  False          7.7
# 743                                        Life Cycles  False          8.8
# 744                        Mythbusters Holiday Special  False          7.5
# 745                                 Ghost Recon: Alpha  False          7.5
# 746                              Red Nose Day Actually  False          7.7
# 747                                      Brain on Fire  False          8.0
# 748                 Duck Dodgers in the 24Â½th Century  False          7.7
# 749                      Black Mirror: White Christmas  False          8.3
# 750                                            Dunkirk  False          7.5
# 751                                    What the Health  False          7.9
# 752                                      Descendants 2  False          7.5
# 753                                     In a Heartbeat  False          8.3
#
#     vote_count
# 0         5415
# 1         1886
# 2         1343
# 3         5915
# 4         3334
# 5         3404
# 6         2632
# 7           71
# 8           45
# 9          984
# 10          91
# 11        6778
# 12         106
# 13        8670
# 14        8358
# 15         943
# 16        8147
# 17        5520
# 18         805
# 19          56
# 20         363
# 21        4956
# 22         105
# 23        1019
# 24         213
# 25        4436
# 26        3833
# 27        2135
# 28         762
# 29        4274
# ..         ...
# 724        249
# 725         41
# 726         45
# 727         32
# 728         37
# 729         43
# 730         38
# 731         50
# 732        549
# 733        725
# 734         72
# 735         25
# 736         34
# 737         84
# 738         50
# 739         26
# 740         41
# 741         35
# 742        795
# 743         27
# 744         88
# 745         43
# 746         29
# 747         41
# 748         36
# 749        211
# 750       2712
# 751         46
# 752        171
# 753        146
#
# [754 rows x 24 columns]

# %% [markdown]
# ## 2. Combine Wikipedia and IMDb plot summaries
# <p>The dataset we imported currently contains two columns titled <code>wiki_plot</code> and <code>imdb_plot</code>. They are the plot found for the movies on Wikipedia and IMDb, respectively. The text in the two columns is similar, however, they are often written in different tones and thus provide context on a movie in a different manner of linguistic expression. Further, sometimes the text in one column may mention a feature of the plot that is not present in the other column. For example, consider the following plot extracts from <em>The Godfather</em>:</p>
# <ul>
# <li>Wikipedia: "On the day of his only daughter's wedding, Vito Corleone"</li>
# <li>IMDb: "In late summer 1945, guests are gathered for the wedding reception of Don Vito Corleone's daughter Connie"</li>
# </ul>
# <p>While the Wikipedia plot only mentions it is the day of the daughter's wedding, the IMDb plot also mentions the year of the scene and the name of the daughter. </p>
# <p>Let's combine both the columns to avoid the overheads in computation associated with extra columns to process.</p>

# %%
# Combine wiki_plot and imdb_plot into a single column
movies_df["plot"] = movies_df["overview"].astype(str)

# Inspect the new DataFrame
movies_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  60000000
# 2  False                                                NaN  52000000
# 3  False                                                NaN  33000000
# 4  False                                                NaN   6000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 3  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#                                             homepage   id    imdb_id  \
# 0               http://toystory.disney.com/toy-story  862  tt0114709
# 1                                                NaN  949  tt0113277
# 2                                                NaN  524  tt0112641
# 3                         http://www.sevenmovie.com/  807  tt0114369
# 4  http://www.mgm.com/#/our-titles/2083/The-Usual...  629  tt0114814
#
#   original_language      original_title  \
# 0                en           Toy Story
# 1                en                Heat
# 2                en              Casino
# 3                en               Se7en
# 4                en  The Usual Suspects
#
#                                             overview  ...    revenue runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  373554033      81
# 1  Obsessive master thief, Neil McCauley leads a ...  ...  187436818     170
# 2  The life of the gambling paradise â€“ Las Vega...  ...  116112375     178
# 3  Two homicide detectives are on a desperate hun...  ...  327311859     127
# 4  Held in an L.A. interrogation room, Verbal Kin...  ...   23341568     106
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4  [{'iso_639_1': 'es', 'name': 'EspaÃ±ol'}, {'is...  Released
#
#                                         tagline               title  video  \
# 0                                           NaN           Toy Story  False
# 1                      A Los Angeles Crime Saga                Heat  False
# 2              No one stays at the top forever.              Casino  False
# 3         Seven deadly sins. Seven ways to die.               Se7en  False
# 4  Five Criminals. One Line Up. No Coincidence.  The Usual Suspects  False
#
#   vote_average vote_count                                               plot
# 0          7.7       5415  Led by Woody, Andy's toys live happily in his ...
# 1          7.7       1886  Obsessive master thief, Neil McCauley leads a ...
# 2          7.8       1343  The life of the gambling paradise â€“ Las Vega...
# 3          8.1       5915  Two homicide detectives are on a desperate hun...
# 4          8.1       3334  Held in an L.A. interrogation room, Verbal Kin...
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 3. Tokenization
# <p>Tokenization is the process  by which we break down articles into individual sentences or words, as needed. Besides the tokenization method provided by NLTK, we might have to perform additional filtration to remove tokens which are entirely numeric values or punctuation.</p>
# <p>While a program may fail to build context from "While waiting at a bus stop in 1981" (<em>Forrest Gump</em>), because this string would not match in any dictionary, it is possible to build context from the words "while", "waiting" or "bus" because they are present in the English dictionary. </p>
# <p>Let us perform tokenization on a small extract from <em>The Godfather</em>.</p>

# %%
# Remove tokens that do not contain any letters from words_tokenized
import re

# %% [markdown]
# ## 4. Stemming
# <p>Stemming is the process by which we bring down a word from its different forms to the root word. This helps us establish meaning to different forms of the same words without having to deal with each form separately. For example, the words 'fishing', 'fished', and 'fisher' all get stemmed to the word 'fish'.</p>
# <p>Consider the following sentences:</p>
# <ul>
# <li>"Young William Wallace witnesses the treachery of Longshanks" ~ <em>Gladiator</em></li>
# <li>"escapes to the city walls only to witness Cicero's death" ~ <em>Braveheart</em></li>
# </ul>
# <p>Instead of building separate dictionary entries for both witnesses and witness, which mean the same thing outside of quantity, stemming them reduces them to 'wit'.</p>
# <p>There are different algorithms available for stemming such as the Porter Stemmer, Snowball Stemmer, etc. We shall use the Snowball Stemmer.</p>

# %%
# Import the SnowballStemmer to perform stemming
# ... YOUR CODE FOR TASK 4 ...
from nltk.stem.snowball import SnowballStemmer

# Create an English language SnowballStemmer object
stemmer = SnowballStemmer("english")

# %% [markdown]
# ## 5. Club together Tokenize & Stem
# <p>We are now able to tokenize and stem sentences. But we may have to use the two functions repeatedly one after the other to handle a large amount of data, hence we can think of wrapping them in a function and passing the text to be tokenized and stemmed as the function argument. Then we can pass the new wrapping function, which shall perform both tokenizing and stemming instead of just tokenizing, as the tokenizer argument while creating the TF-IDF vector of the text.  </p>
# <p>What difference does it make though? Consider the sentence from the plot of <em>The Godfather</em>: "Today (May 19, 2016) is his only daughter's wedding." If we do a 'tokenize-only' for this sentence, we have the following result:</p>
# <blockquote>
#   <p>'today', 'may', 'is', 'his', 'only', 'daughter', "'s", 'wedding'</p>
# </blockquote>
# <p>But when we do a 'tokenize-and-stem' operation we get:</p>
# <blockquote>
#   <p>'today', 'may', 'is', 'his', 'onli', 'daughter', "'s", 'wed'</p>
# </blockquote>
# <p>All the words are in their root form, which will lead to a better establishment of meaning as some of the non-root forms may not be present in the NLTK training corpus.</p>

# %%
# Define a function to perform both stemming and tokenization
def tokenize_and_stem(text):
    
    # Tokenize by sentence, then by word
    tokens = [y for x in nltk.sent_tokenize(text) for y in nltk.word_tokenize(x)]
    
    # Filter out raw tokens to remove noise
    filtered_tokens = [token for token in tokens if re.search('[a-zA-Z]', token)]
    
    # Stem the filtered_tokens
    stems = [stemmer.stem(word) for word in filtered_tokens]
    
    return stems

# %% [markdown]
# ## 6. Create TfidfVectorizer
# <p>Computers do not <em>understand</em> text. These are machines only capable of understanding numbers and performing numerical computation. Hence, we must convert our textual plot summaries to numbers for the computer to be able to extract meaning from them. One simple method of doing this would be to count all the occurrences of each word in the entire vocabulary and return the counts in a vector. Enter <code>CountVectorizer</code>.</p>
# <p>Consider the word 'the'. It appears quite frequently in almost all movie plots and will have a high count in each case. But obviously, it isn't the theme of all the movies! <a href="https://campus.datacamp.com/courses/natural-language-processing-fundamentals-in-python/simple-topic-identification?ex=11">Term Frequency-Inverse Document Frequency</a> (TF-IDF) is one method which overcomes the shortcomings of <code>CountVectorizer</code>. The Term Frequency of a word is the measure of how often it appears in a document, while the Inverse Document Frequency is the parameter which reduces the importance of a word if it frequently appears in several documents.</p>
# <p>For example, when we apply the TF-IDF on the first 3 sentences from the plot of <em>The Wizard of Oz</em>, we are told that the most important word there is 'Toto', the pet dog of the lead character. This is because the movie begins with 'Toto' biting someone due to which the journey of Oz begins!</p>
# <p>In simplest terms, TF-IDF recognizes words which are unique and important to any given document. Let's create one for our purposes.</p>

# %%
# Import TfidfVectorizer to create TF-IDF vectors
# ... YOUR CODE FOR TASK 6 ...

from sklearn.feature_extraction.text import TfidfVectorizer

# Instantiate TfidfVectorizer object with stopwords and tokenizer
# parameters for efficient processing of text
tfidf_vectorizer = TfidfVectorizer(max_df=0.95,
                                 stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem,
                                 ngram_range=(1,2))

# %% [markdown]
# ## 7. Fit transform TfidfVectorizer
# <p>Once we create a TF-IDF Vectorizer, we must fit the text to it and then transform the text to produce the corresponding numeric form of the data which the computer will be able to understand and derive meaning from. To do this, we use the <code>fit_transform()</code> method of the <code>TfidfVectorizer</code> object. </p>
# <p>If we observe the <code>TfidfVectorizer</code> object we created, we come across a parameter stopwords. 'stopwords' are those words in a given text which do not contribute considerably towards the meaning of the sentence and are generally grammatical filler words. For example, in the sentence 'Dorothy Gale lives with her dog Toto on the farm of her Aunt Em and Uncle Henry', we could drop the words 'her' and 'the', and still have a similar overall meaning to the sentence. Thus, 'her' and 'the' are stopwords and can be conveniently dropped from the sentence. </p>
# <p>On setting the stopwords to 'english', we direct the vectorizer to drop all stopwords from a pre-defined list of English language stopwords present in the nltk module. Another parameter, <code>ngram_range</code>, defines the length of the ngrams to be formed while vectorizing the text.</p>

# %%
# Fit and transform the tfidf_vectorizer with the "plot" of each movie
# to create a vector representation of the plot summaries
tfidf_matrix = tfidf_vectorizer.fit_transform([x for x in movies_df["plot"]])

print(tfidf_matrix.shape)
# Out:
# (754, 25904)

# %% [markdown]
# ## 8. Import KMeans and create clusters
# <p>To determine how closely one movie is related to the other by the help of unsupervised learning, we can use clustering techniques. Clustering is the method of grouping together a number of items such that they exhibit similar properties. According to the measure of similarity desired, a given sample of items can have one or more clusters. </p>
# <p>A good basis of clustering in our dataset could be the genre of the movies. Say we could have a cluster '0' which holds movies of the 'Drama' genre. We would expect movies like <em>Chinatown</em> or <em>Psycho</em> to belong to this cluster. Similarly, the cluster '1' in this project holds movies which belong to the 'Adventure' genre (<em>Lawrence of Arabia</em> and the <em>Raiders of the Lost Ark</em>, for example).</p>
# <p>K-means is an algorithm which helps us to implement clustering in Python. The name derives from its method of implementation: the given sample is divided into <b><i>K</i></b> clusters where each cluster is denoted by the <b><i>mean</i></b> of all the items lying in that cluster. </p>
# <p>We get the following distribution for the clusters:</p>
# <p><img src="https://assets.datacamp.com/production/project_648/img/bar_clusters.png" alt="bar graph of clusters"></p>

# %%
from sklearn.metrics.pairwise import linear_kernel

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_sim[0]
movies_df = movies_df.reset_index(drop=True)
titles = movies_df['original_title']
indices = pd.Series(movies_df.index, index=movies_df['original_title'])

def get_recommendations(original_title):
    idx = indices[original_title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)
    sim_scores = sim_scores[1:10]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

get_recommendations('Toy Story')
# Out:
# 473                                 Toy Story 3
# 79                        Rebel Without a Cause
# 542                  Woody Allen: A Documentary
# 278    Harry Potter and the Philosopher's Stone
# 676                   Hunt for the Wilderpeople
# 357                                The Notebook
# 14                     The Shawshank Redemption
# 430                   In the Shadow of the Moon
# 68                             Bringing Up Baby
# Name: original_title, dtype: object

# %% [markdown]
# ## 9. Calculate similarity distance
# <p>Consider the following two sentences from the movie <em>The Wizard of Oz</em>: </p>
# <blockquote>
#   <p>"they find in the Emerald City"</p>
#   <p>"they finally reach the Emerald City"</p>
# </blockquote>
# <p>If we put the above sentences in a <code>CountVectorizer</code>, the vocabulary produced would be "they, find, in, the, Emerald, City, finally, reach" and the vectors for each sentence would be as follows: </p>
# <blockquote>
#   <p>1, 1, 1, 1, 1, 1, 0, 0</p>
#   <p>1, 0, 0, 1, 1, 1, 1, 1</p>
# </blockquote>
# <p>When we calculate the cosine angle formed between the vectors represented by the above, we get a score of 0.667. This means the above sentences are very closely related. <em>Similarity distance</em> is 1 - <a href="https://en.wikipedia.org/wiki/Cosine_similarity">cosine similarity angle</a>. This follows from that if the vectors are similar, the cosine of their angle would be 1 and hence, the distance between then would be 1 - 1 = 0.</p>
# <p>Let's calculate the similarity distance for all of our movies.</p>

# %%
# Import cosine_similarity to calculate similarity of movie plots
from sklearn.metrics.pairwise import cosine_similarity

# Calculate the similarity distance
similarity_distance = 1 - cosine_similarity(tfidf_matrix)

print(len(similarity_distance[0]))
# Out:
# 754

# %% [markdown]
# ## 10. Import Matplotlib, Linkage, and Dendrograms
# <p>We shall now create a tree-like diagram (called a dendrogram) of the movie titles to help us understand the level of similarity between them visually. Dendrograms help visualize the results of hierarchical clustering, which is an alternative to k-means clustering. Two pairs of movies at the same level of hierarchical clustering are expected to have similar strength of similarity between the corresponding pairs of movies. For example, the movie <em>Fargo</em> would be as similar to <em>North By Northwest</em> as the movie <em>Platoon</em> is to <em>Saving Private Ryan</em>, given both the pairs exhibit the same level of the hierarchy.</p>
# <p>Let's import the modules we'll need to create our dendrogram.</p>

# %%
# Import matplotlib.pyplot for plotting graphs
# ... YOUR CODE FOR TASK 10 ...

import matplotlib.pyplot as plt

# Configure matplotlib to display the output inline
# %matplotlib inline

# Import modules necessary to plot dendrogram
# ... YOUR CODE FOR TASK 10 ...

from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import linkage

# %% [markdown]
# ## 11. Create merging and plot dendrogram
# <p>We shall plot a dendrogram of the movies whose similarity measure will be given by the similarity distance we previously calculated. The lower the similarity distance between any two movies, the lower their linkage will make an intercept on the y-axis. For instance, the lowest dendrogram linkage we shall discover will be between the movies, <em>It's a Wonderful Life</em> and <em>A Place in the Sun</em>. This indicates that the movies are very similar to each other in their plots.</p>

# %%
# Create mergings matrix 
mergings = linkage(similarity_distance, method='complete')

# Plot the dendrogram, using title as label column
dendrogram_ = dendrogram(mergings,
               labels=[x for x in movies_df["title"]],
               leaf_rotation=90,
               leaf_font_size=8,
)

# Adjust the plot
fig = plt.gcf()
_ = [lbl.set_color('r') for lbl in plt.gca().get_xmajorticklabels()]
fig.set_size_inches(108, 21)

# Show the plotted dendrogram
plt.show()

# %% [markdown]
# ## 12. Which movies are most similar?
# <p>We can now determine the similarity between movies based on their plots! To wrap up, let's answer one final question: which movie is most similar to the movie <em>Braveheart</em>?</p>

# %%
# Answer the question 
ans = "Gladiator"
print(ans)
# Out:
# Gladiator
