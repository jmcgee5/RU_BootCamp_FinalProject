# %% [markdown]
# ## 1. Import and observe dataset
# <p>We all love watching movies! There are some movies we like, some we don't. Most people have a preference for movies of a similar genre. Some of us love watching action movies, while some of us like watching horror. Some of us like watching movies that have ninjas in them, while some of us like watching superheroes.</p>
# <p>Movies within a genre often share common base parameters. Consider the following two movies:</p>
# <p><img style="margin:5px 20px 5px 1px; height: 250px; display: inline-block;" alt="2001: A Space Odyssey" src="https://assets.datacamp.com/production/project_648/img/movie1.jpg">
# <img style="margin:5px 20px 5px 1px; height: 250px; display: inline-block;" alt="Close Encounters of the Third Kind" src="https://assets.datacamp.com/production/project_648/img/movie2.jpg"></p>
# <p>Both movies, <em>2001: A Space Odyssey</em> and <em>Close Encounters of the Third Kind</em>, are movies based on aliens coming to Earth. I've seen both, and they indeed share many similarities. We could conclude that both of these fall into the same genre of movies based on intuition, but that's no fun in a data science context. In this notebook, we will quantify the similarity of movies based on their plot summaries available on IMDb and Wikipedia, then separate them into groups, also known as clusters. We'll create a dendrogram to represent how closely the movies are related to each other.</p>
# <p>Let's start by importing the dataset and observing the data provided.</p>

# %%
# Import modules
import numpy as np
import pandas as pd
import nltk

# Set seed for reproducibility
np.random.seed(5)

# Read in IMDb and Wikipedia movie data (both in same file)
movies_df = pd.read_csv("datasets/movies_final.csv")

print("Number of movies loaded: %s " % (len(movies_df)))

# Display the data
movies_df
# Out:
# Number of movies loaded: 10712
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5      False                                                NaN  60000000
# 6      False                                                NaN  58000000
# 7      False                                                NaN         0
# 8      False                                                NaN  35000000
# 9      False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10     False                                                NaN  62000000
# 11     False                                                NaN         0
# 12     False  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 13     False                                                NaN  44000000
# 14     False                                                NaN  98000000
# 15     False                                                NaN  52000000
# 16     False                                                NaN  16500000
# 17     False                                                NaN   4000000
# 18     False  {'id': 3167, 'name': 'Ace Ventura Collection',...  30000000
# 19     False                                                NaN  60000000
# 20     False  {'id': 91698, 'name': 'Chili Palmer Collection...  30250000
# 21     False                                                NaN         0
# 22     False                                                NaN  50000000
# 23     False                                                NaN         0
# 24     False                                                NaN   3600000
# 25     False                                                NaN         0
# 26     False                                                NaN  12000000
# 27     False                                                NaN         0
# 28     False                                                NaN         0
# 29     False                                                NaN  29500000
# ...      ...                                                ...       ...
# 10682  False                                                NaN  15000000
# 10683  False                                                NaN         0
# 10684  False                                                NaN         0
# 10685  False                                                NaN    500000
# 10686  False                                                NaN         0
# 10687  False                                                NaN         0
# 10688  False  {'id': 14246, 'name': 'Sniper Collection', 'po...         0
# 10689  False  {'id': 86066, 'name': 'Despicable Me Collectio...         0
# 10690  False                                                NaN  50000000
# 10691  False                                                NaN         0
# 10692  False                                                NaN         0
# 10693  False                                                NaN  11000000
# 10694  False                                                NaN         0
# 10695  False                                                NaN         0
# 10696  False                                                NaN         0
# 10697  False                                                NaN         0
# 10698  False                                                NaN  34000000
# 10699  False                                                NaN         0
# 10700  False                                                NaN         0
# 10701  False                                                NaN         0
# 10702  False  {'id': 466463, 'name': 'Descendants Collection...         0
# 10703  False                                                NaN         0
# 10704  False                                                NaN         0
# 10705  False  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 10706  False  {'id': 37261, 'name': 'The Carry On Collection...         0
# 10707  False                                                NaN         0
# 10708  False                                                NaN         0
# 10709  False                                                NaN         0
# 10710  False                                                NaN         0
# 10711  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# 5      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6      [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9      [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 10     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 11     [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12     [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 13     [{'id': 36, 'name': 'History'}, {'id': 18, 'na...
# 14     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 16     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 17     [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 18     [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 19     [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 20     [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...
# 21     [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 22     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 23     [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 24     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 25                         [{'id': 18, 'name': 'Drama'}]
# 26     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 27     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 28     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 29     [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# ...                                                  ...
# 10682                     [{'id': 28, 'name': 'Action'}]
# 10683  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 10684  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 10685  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 10686  [{'id': 35, 'name': 'Comedy'}, {'id': 10770, '...
# 10687  [{'id': 10402, 'name': 'Music'}, {'id': 18, 'n...
# 10688  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 10689  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 10690  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 10691  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 10692  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10693  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10694  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 10695  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 10696  [{'id': 14, 'name': 'Fantasy'}, {'id': 27, 'na...
# 10697                     [{'id': 35, 'name': 'Comedy'}]
# 10698  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 10699                      [{'id': 18, 'name': 'Drama'}]
# 10700  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 10701  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 10702  [{'id': 10770, 'name': 'TV Movie'}, {'id': 107...
# 10703  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10704  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 10705  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 10706                     [{'id': 35, 'name': 'Comedy'}]
# 10707  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 10708  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 10709  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 10710                     [{'id': 35, 'name': 'Comedy'}]
# 10711  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
#
#                                                 homepage      id    imdb_id  \
# 0                   http://toystory.disney.com/toy-story     862  tt0114709
# 1                                                    NaN    8844  tt0113497
# 2                                                    NaN   15602  tt0113228
# 3                                                    NaN   31357  tt0114885
# 4                                                    NaN   11862  tt0113041
# 5                                                    NaN     949  tt0113277
# 6                                                    NaN   11860  tt0114319
# 7                                                    NaN   45325  tt0112302
# 8                                                    NaN    9091  tt0114576
# 9           http://www.mgm.com/view/movie/757/Goldeneye/     710  tt0113189
# 10                                                   NaN    9087  tt0112346
# 11                                                   NaN   12110  tt0112896
# 12                                                   NaN   21032  tt0112453
# 13                                                   NaN   10858  tt0113987
# 14                                                   NaN    1408  tt0112760
# 15                                                   NaN     524  tt0112641
# 16                                                   NaN    4584  tt0114388
# 17                                                   NaN       5  tt0113101
# 18                                                   NaN    9273  tt0112281
# 19                                                   NaN   11517  tt0113845
# 20                                                   NaN    8012  tt0113161
# 21                                                   NaN    1710  tt0112722
# 22                                                   NaN    9691  tt0112401
# 23                                                   NaN   12665  tt0114168
# 24     http://www.mgm.com/title_title.do?title_star=L...     451  tt0113627
# 25                                                   NaN   16420  tt0114057
# 26                                                   NaN    9263  tt0114011
# 27                                                   NaN   17015  tt0114117
# 28                                                   NaN    9909  tt0112792
# 29                                                   NaN      63  tt0114746
# ...                                                  ...     ...        ...
# 10682                                                NaN  460846  tt3501112
# 10683              http://www.overdrivemovie.co.uk/home/  404733  tt1935194
# 10684                                                NaN   32593  tt0255605
# 10685                                                NaN  401132  tt5720450
# 10686                http://www.hbo.com/tour-de-pharmacy  458506  tt5886510
# 10687              http://abc.go.com/shows/dirty-dancing  444902  tt5262792
# 10688                                                NaN   14247  tt0408196
# 10689                                                NaN   54551  tt1814643
# 10690                     http://www.theemoji-movie.com/  378236  tt4877122
# 10691                                                NaN  407531  tt4998772
# 10692                                                NaN  463906  tt2569088
# 10693                                                NaN  395834  tt5362988
# 10694                                                NaN  339692  tt4633690
# 10695        https://www.youtube.com/watch?v=pKWB-MVJ4sQ  464111  tt7078780
# 10696                          http://wishuponmovie.com/  440597  tt5322012
# 10697                                                NaN  417870  tt3564472
# 10698                               http://detroit.movie  407448  tt5390504
# 10699                                                NaN  459950  tt5226512
# 10700                                                NaN  410554  tt5884234
# 10701                                                NaN   54559  tt1830748
# 10702                                                NaN  417320  tt5117876
# 10703                                                NaN   44918  tt1640571
# 10704                                                NaN   28669  tt0059635
# 10705                                                NaN    3104  tt0061683
# 10706                                                NaN   19307  tt0064133
# 10707                                                NaN  426272  tt6598626
# 10708             https://www.netflix.com/title/80171022  432789  tt5990342
# 10709                                                NaN  455661  tt6969946
# 10710                                                NaN   14008  tt0294425
# 10711                                                NaN   30840  tt0102797
#
#       original_language                  original_title  \
# 0                    en                       Toy Story
# 1                    en                         Jumanji
# 2                    en                Grumpier Old Men
# 3                    en               Waiting to Exhale
# 4                    en     Father of the Bride Part II
# 5                    en                            Heat
# 6                    en                         Sabrina
# 7                    en                    Tom and Huck
# 8                    en                    Sudden Death
# 9                    en                       GoldenEye
# 10                   en          The American President
# 11                   en     Dracula: Dead and Loving It
# 12                   en                           Balto
# 13                   en                           Nixon
# 14                   en                Cutthroat Island
# 15                   en                          Casino
# 16                   en           Sense and Sensibility
# 17                   en                      Four Rooms
# 18                   en  Ace Ventura: When Nature Calls
# 19                   en                     Money Train
# 20                   en                      Get Shorty
# 21                   en                         Copycat
# 22                   en                       Assassins
# 23                   en                          Powder
# 24                   en               Leaving Las Vegas
# 25                   en                         Othello
# 26                   en                    Now and Then
# 27                   en                      Persuasion
# 28                   en                 Dangerous Minds
# 29                   en                  Twelve Monkeys
# ...                 ...                             ...
# 10682                en                        Security
# 10683                en                       Overdrive
# 10684                en                      Snow White
# 10685                en               Independents' Day
# 10686                en                Tour de Pharmacy
# 10687                en                   Dirty Dancing
# 10688                en                        Sniper 3
# 10689                en                          Banana
# 10690                en                 The Emoji Movie
# 10691                en                       Bedeviled
# 10692                en                       The Saint
# 10693                en                      Wind River
# 10694                en                     Shot Caller
# 10695                en                          Zygote
# 10696                en                       Wish Upon
# 10697                en                      Girls Trip
# 10698                en                         Detroit
# 10699                en                            Feed
# 10700                en                      First Kill
# 10701                en        Minions: Orientation Day
# 10702                en                   Descendants 2
# 10703                en                      Titanic II
# 10704                en          Rasputin: The Mad Monk
# 10705                en      Frankenstein Created Woman
# 10706                en                Carry On Camping
# 10707                en                         Take Me
# 10708                en    The Incredible Jessica James
# 10709                en                  In a Heartbeat
# 10710                en                     Cadet Kelly
# 10711                en                      Robin Hood
#
#                                                 overview  ...  release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...    10/30/1995
# 1      When siblings Judy and Peter discover an encha...  ...    12/15/1995
# 2      A family wedding reignites the ancient feud be...  ...    12/22/1995
# 3      Cheated on, mistreated and stepped on, the wom...  ...    12/22/1995
# 4      Just when George Banks has recovered from his ...  ...     2/10/1995
# 5      Obsessive master thief, Neil McCauley leads a ...  ...    12/15/1995
# 6      An ugly duckling having undergone a remarkable...  ...    12/15/1995
# 7      A mischievous young boy, Tom Sawyer, witnesses...  ...    12/22/1995
# 8      International action superstar Jean Claude Van...  ...    12/22/1995
# 9      James Bond must unmask the mysterious head of ...  ...    11/16/1995
# 10     Widowed U.S. president Andrew Shepherd, one of...  ...    11/17/1995
# 11     When a lawyer shows up at the vampire's doorst...  ...    12/22/1995
# 12     An outcast half-wolf risks his life to prevent...  ...    12/22/1995
# 13     An all-star cast powers this epic look at Amer...  ...    12/22/1995
# 14     Morgan Adams and her slave, William Shaw, are ...  ...    12/22/1995
# 15     The life of the gambling paradise – Las Vegas ...  ...    11/22/1995
# 16     Rich Mr. Dashwood dies, leaving his second wif...  ...    12/13/1995
# 17     It's Ted the Bellhop's first night on the job....  ...     12/9/1995
# 18     Summoned from an ashram in Tibet, Ace finds hi...  ...    11/10/1995
# 19     A vengeful New York transit cop decides to ste...  ...    11/21/1995
# 20     Chili Palmer is a Miami mobster who gets sent ...  ...    10/20/1995
# 21     An agoraphobic psychologist and a female detec...  ...    10/27/1995
# 22     Assassin Robert Rath arrives at a funeral to k...  ...     10/6/1995
# 23     Harassed by classmates who won't accept his sh...  ...    10/27/1995
# 24     Ben Sanderson, an alcoholic Hollywood screenwr...  ...    10/27/1995
# 25     The evil Iago pretends to be friend of Othello...  ...    12/15/1995
# 26     Waxing nostalgic about the bittersweet passage...  ...    10/20/1995
# 27     This film adaptation of Jane Austen's last nov...  ...     9/27/1995
# 28     Former Marine Louanne Johnson lands a gig teac...  ...     8/11/1995
# 29     In the year 2035, convict James Cole reluctant...  ...    12/29/1995
# ...                                                  ...  ...           ...
# 10682  An ex-special services veteran, down on his lu...  ...      3/4/2017
# 10683  Master car thieves square off against French g...  ...     6/29/2017
# 10684  Snow White's mother dies during childbirth, le...  ...    10/28/2001
# 10685  Aliens invade, this time delivering a clear ul...  ...      6/7/2016
# 10686  A mockumentary that chronicles the prevalence ...  ...      7/8/2017
# 10687  Spending the summer at a Catskills resort with...  ...     5/24/2017
# 10688  Master Gunnery Sergeant Thomas Beckett is the ...  ...    10/18/2004
# 10689  The Minions fight over a delicious banana.. bu...  ...    12/13/2010
# 10690  Gene, a multi-expressional emoji, sets out on ...  ...     7/28/2017
# 10691  A group of friends download a Siri-like App wh...  ...     6/28/2017
# 10692  International master thief, Simon Templar, als...  ...     7/11/2017
# 10693  An FBI agent teams with the town's veteran gam...  ...      8/3/2017
# 10694  A newly-released prison gangster is forced by ...  ...     7/13/2017
# 10695  Stranded in an Arctic mine, two survivors are ...  ...     7/12/2017
# 10696  A teenage girl discovers a box with magical po...  ...      7/7/2017
# 10697  Four girlfriends take a trip to New Orleans fo...  ...     7/21/2017
# 10698  A police raid in Detroit in 1967 results in on...  ...     7/28/2017
# 10699  Olivia and Matthew Grey, 18-year-old twins bor...  ...     7/18/2017
# 10700  A police chief tries to solve a kidnapping tha...  ...     7/21/2017
# 10701  With so many jobs to choose from, the Minions ...  ...    12/13/2010
# 10702  When the pressure to be royal becomes too much...  ...     7/21/2017
# 10703  On the 100th anniversary of the original voyag...  ...      8/7/2010
# 10704  Rasputin, a crazed and debauched monk wreaks h...  ...      3/6/1966
# 10705  A deformed tormented girl drowns herself after...  ...     3/15/1967
# 10706  Sid and Bernie keep having their amorous inten...  ...     5/29/1969
# 10707  Ray is a fledgling entrepreneur who specialize...  ...      5/5/2017
# 10708  Burned by a bad breakup, a struggling New York...  ...     1/27/2017
# 10709  A closeted boy runs the risk of being outed by...  ...      6/1/2017
# 10710  Hyperactive teenager Kelly is enrolled into a ...  ...      3/7/2002
# 10711  Yet another version of the classic epic, with ...  ...     5/13/1991
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5      187436818.0   170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6              0.0   127.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 7              0.0    97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 8       64350171.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9      352194034.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 10     107879496.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 11             0.0    88.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 12      11348324.0    78.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 13      13681765.0   192.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14      10017322.0   119.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 15     116112375.0   178.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 16     135000000.0   136.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 17       4300000.0    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 18     212385533.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 19      35431113.0   103.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 20     115101622.0   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 21             0.0   124.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 22      30303072.0   132.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 23             0.0   111.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 24      49800000.0   112.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 25             0.0   123.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 26      27400000.0   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 27             0.0   104.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 28     180000000.0    99.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 29     168840000.0   129.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ...            ...     ...                                                ...
# 10682          0.0    87.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10683          0.0    93.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 10684          0.0    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10685          0.0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10686          0.0    41.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10687          0.0   130.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10688          0.0    97.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10689          0.0     4.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 10690   66913939.0    86.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10691          0.0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10692          0.0    92.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 10693  184770205.0   111.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10694          0.0   121.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10695          0.0    23.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10696          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10697          0.0   122.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10698          0.0   143.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10699          0.0    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10700          0.0    97.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10701          0.0     4.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 10702          0.0   111.0             [{'iso_639_1': 'da', 'name': 'Dansk'}]
# 10703          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10704          0.0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10705          0.0    92.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10706          0.0    88.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10707          0.0    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10708          0.0    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10709          0.0     4.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10710          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10711          0.0   104.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# 5      Released                           A Los Angeles Crime Saga
# 6      Released  You are cordially invited to the most surprisi...
# 7      Released                             The Original Bad Boys.
# 8      Released                         Terror goes into overtime.
# 9      Released               No limits. No fears. No substitutes.
# 10     Released  Why can't the most powerful man in the world h...
# 11     Released                                                NaN
# 12     Released                     Part Dog. Part Wolf. All Hero.
# 13     Released  Triumphant in Victory, Bitter in Defeat. He Ch...
# 14     Released  The Course Has Been Set. There Is No Turning B...
# 15     Released                   No one stays at the top forever.
# 16     Released           Lose your heart and come to your senses.
# 17     Released  Twelve outrageous guests. Four scandalous requ...
# 18     Released            New animals. New adventures. Same hair.
# 19     Released                        Get on, or GET OUT THE WAY!
# 20     Released  The mob is tough, but it’s nothing like show b...
# 21     Released  One man is copying the most notorious killers ...
# 22     Released  In the shadows of life, In the business of dea...
# 23     Released  An extraordinary encounter with another human ...
# 24     Released                     I Love You... The Way You Are.
# 25     Released                    Envy, greed, jealousy and love.
# 26     Released  In every woman there is the girl she left behind.
# 27     Released                                                NaN
# 28     Released    She broke the rules... and changed their lives.
# 29     Released                             The future is history.
# ...         ...                                                ...
# 10682  Released                                                NaN
# 10683  Released                                                NaN
# 10684  Released                    Deception never looked so sweet
# 10685  Released                      The revolution begins, again!
# 10686  Released                                                NaN
# 10687  Released                             A musical re-imagining
# 10688  Released                                                NaN
# 10689  Released                                                NaN
# 10690  Released                                 Not easy being meh
# 10691  Released                           Don't accept his invite.
# 10692  Released                                                NaN
# 10693  Released         Nothing is harder to track than the truth.
# 10694  Released                  Some criminals are made in prison
# 10695  Released                                                NaN
# 10696  Released                       Be careful what you wish for
# 10697  Released      "Forgive us in advance for this wild weekend"
# 10698  Released                                  It's time we knew
# 10699  Released                                                NaN
# 10700  Released           When you only have one shot, don't miss.
# 10701  Released                                                NaN
# 10702  Released                                    Long live evil.
# 10703  Released           100 years later, lightning strikes twice
# 10704  Released                     Ladies' Man - And Lady Killer!
# 10705  Released  Now Frankenstein has created a beautiful woman...
# 10706  Released               Fun and games in the great outdoors!
# 10707  Released                    A good hostage is hard to find.
# 10708  Released                      Likes are easy, love is hard.
# 10709  Released               The Heart Wants What The Heart Wants
# 10710  Released                            Too Cool For The Rules!
# 10711  Released                                                NaN
#
#                                      title  video vote_average vote_count
# 0                                Toy Story  False          7.7     5415.0
# 1                                  Jumanji  False          6.9     2413.0
# 2                         Grumpier Old Men  False          6.5       92.0
# 3                        Waiting to Exhale  False          6.1       34.0
# 4              Father of the Bride Part II  False          5.7      173.0
# 5                                     Heat  False          7.7     1886.0
# 6                                  Sabrina  False          6.2      141.0
# 7                             Tom and Huck  False          5.4       45.0
# 8                             Sudden Death  False          5.5      174.0
# 9                                GoldenEye  False          6.6     1194.0
# 10                  The American President  False          6.5      199.0
# 11             Dracula: Dead and Loving It  False          5.7      210.0
# 12                                   Balto  False          7.1      423.0
# 13                                   Nixon  False          7.1       72.0
# 14                        Cutthroat Island  False          5.7      137.0
# 15                                  Casino  False          7.8     1343.0
# 16                   Sense and Sensibility  False          7.2      364.0
# 17                              Four Rooms  False          6.5      539.0
# 18          Ace Ventura: When Nature Calls  False          6.1     1128.0
# 19                             Money Train  False          5.4      224.0
# 20                              Get Shorty  False          6.4      305.0
# 21                                 Copycat  False          6.5      199.0
# 22                               Assassins  False          6.0      394.0
# 23                                  Powder  False          6.3      143.0
# 24                       Leaving Las Vegas  False          7.1      365.0
# 25                                 Othello  False          7.0       33.0
# 26                            Now and Then  False          6.6       91.0
# 27                              Persuasion  False          7.4       36.0
# 28                         Dangerous Minds  False          6.4      249.0
# 29                          Twelve Monkeys  False          7.4     2470.0
# ...                                    ...    ...          ...        ...
# 10682                             Security  False          6.0      113.0
# 10683                            Overdrive  False          6.2       76.0
# 10684  Snow White: The Fairest of Them All  False          5.3       52.0
# 10685                    Independents' Day  False          3.9       25.0
# 10686                     Tour de Pharmacy  False          6.8       36.0
# 10687                        Dirty Dancing  False          5.3       58.0
# 10688                             Sniper 3  False          5.2       28.0
# 10689                               Banana  False          7.2      139.0
# 10690                      The Emoji Movie  False          5.8      327.0
# 10691                            Bedeviled  False          4.9       47.0
# 10692                            The Saint  False          5.8       41.0
# 10693                           Wind River  False          7.4      181.0
# 10694                          Shot Caller  False          6.9      324.0
# 10695                               Zygote  False          7.2       28.0
# 10696                            Wish Upon  False          5.3      127.0
# 10697                           Girls Trip  False          7.1      393.0
# 10698                              Detroit  False          7.3       67.0
# 10699                                 Feed  False          7.3       50.0
# 10700                           First Kill  False          5.2       38.0
# 10701             Minions: Orientation Day  False          7.0       95.0
# 10702                        Descendants 2  False          7.5      171.0
# 10703                            Titanic 2  False          3.4       55.0
# 10704               Rasputin: The Mad Monk  False          5.6       25.0
# 10705           Frankenstein Created Woman  False          5.9       33.0
# 10706                     Carry On Camping  False          6.5       25.0
# 10707                              Take Me  False          6.0       38.0
# 10708         The Incredible Jessica James  False          6.2       37.0
# 10709                       In a Heartbeat  False          8.3      146.0
# 10710                          Cadet Kelly  False          5.2      145.0
# 10711                           Robin Hood  False          5.7       26.0
#
# [10712 rows x 24 columns]

# %% [markdown]
# ## 2. Combine Wikipedia and IMDb plot summaries
# <p>The dataset we imported currently contains two columns titled <code>wiki_plot</code> and <code>imdb_plot</code>. They are the plot found for the movies on Wikipedia and IMDb, respectively. The text in the two columns is similar, however, they are often written in different tones and thus provide context on a movie in a different manner of linguistic expression. Further, sometimes the text in one column may mention a feature of the plot that is not present in the other column. For example, consider the following plot extracts from <em>The Godfather</em>:</p>
# <ul>
# <li>Wikipedia: "On the day of his only daughter's wedding, Vito Corleone"</li>
# <li>IMDb: "In late summer 1945, guests are gathered for the wedding reception of Don Vito Corleone's daughter Connie"</li>
# </ul>
# <p>While the Wikipedia plot only mentions it is the day of the daughter's wedding, the IMDb plot also mentions the year of the scene and the name of the daughter. </p>
# <p>Let's combine both the columns to avoid the overheads in computation associated with extra columns to process.</p>

# %%
# Combine wiki_plot and imdb_plot into a single column
movies_df["plot"] = movies_df["overview"].astype(str)

# Inspect the new DataFrame
movies_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...      revenue  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  373554033.0
# 1  When siblings Judy and Peter discover an encha...  ...  262797249.0
# 2  A family wedding reignites the ancient feud be...  ...          0.0
# 3  Cheated on, mistreated and stepped on, the wom...  ...   81452156.0
# 4  Just when George Banks has recovered from his ...  ...   76578911.0
#
#   runtime                                   spoken_languages    status  \
# 0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2   101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3   127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4   106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count  \
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
#                                                 plot
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 3. Tokenization
# <p>Tokenization is the process  by which we break down articles into individual sentences or words, as needed. Besides the tokenization method provided by NLTK, we might have to perform additional filtration to remove tokens which are entirely numeric values or punctuation.</p>
# <p>While a program may fail to build context from "While waiting at a bus stop in 1981" (<em>Forrest Gump</em>), because this string would not match in any dictionary, it is possible to build context from the words "while", "waiting" or "bus" because they are present in the English dictionary. </p>
# <p>Let us perform tokenization on a small extract from <em>The Godfather</em>.</p>

# %%
# Remove tokens that do not contain any letters from words_tokenized
import re

# %% [markdown]
# ## 4. Stemming
# <p>Stemming is the process by which we bring down a word from its different forms to the root word. This helps us establish meaning to different forms of the same words without having to deal with each form separately. For example, the words 'fishing', 'fished', and 'fisher' all get stemmed to the word 'fish'.</p>
# <p>Consider the following sentences:</p>
# <ul>
# <li>"Young William Wallace witnesses the treachery of Longshanks" ~ <em>Gladiator</em></li>
# <li>"escapes to the city walls only to witness Cicero's death" ~ <em>Braveheart</em></li>
# </ul>
# <p>Instead of building separate dictionary entries for both witnesses and witness, which mean the same thing outside of quantity, stemming them reduces them to 'wit'.</p>
# <p>There are different algorithms available for stemming such as the Porter Stemmer, Snowball Stemmer, etc. We shall use the Snowball Stemmer.</p>

# %%
# Import the SnowballStemmer to perform stemming
# ... YOUR CODE FOR TASK 4 ...
from nltk.stem.snowball import SnowballStemmer

# Create an English language SnowballStemmer object
stemmer = SnowballStemmer("english")

# %% [markdown]
# ## 5. Club together Tokenize & Stem
# <p>We are now able to tokenize and stem sentences. But we may have to use the two functions repeatedly one after the other to handle a large amount of data, hence we can think of wrapping them in a function and passing the text to be tokenized and stemmed as the function argument. Then we can pass the new wrapping function, which shall perform both tokenizing and stemming instead of just tokenizing, as the tokenizer argument while creating the TF-IDF vector of the text.  </p>
# <p>What difference does it make though? Consider the sentence from the plot of <em>The Godfather</em>: "Today (May 19, 2016) is his only daughter's wedding." If we do a 'tokenize-only' for this sentence, we have the following result:</p>
# <blockquote>
#   <p>'today', 'may', 'is', 'his', 'only', 'daughter', "'s", 'wedding'</p>
# </blockquote>
# <p>But when we do a 'tokenize-and-stem' operation we get:</p>
# <blockquote>
#   <p>'today', 'may', 'is', 'his', 'onli', 'daughter', "'s", 'wed'</p>
# </blockquote>
# <p>All the words are in their root form, which will lead to a better establishment of meaning as some of the non-root forms may not be present in the NLTK training corpus.</p>

# %%
# Define a function to perform both stemming and tokenization
def tokenize_and_stem(text):
    
    # Tokenize by sentence, then by word
    tokens = [y for x in nltk.sent_tokenize(text) for y in nltk.word_tokenize(x)]
    
    # Filter out raw tokens to remove noise
    filtered_tokens = [token for token in tokens if re.search('[a-zA-Z]', token)]
    
    # Stem the filtered_tokens
    stems = [stemmer.stem(word) for word in filtered_tokens]
    
    return stems

# %% [markdown]
# ## 6. Create TfidfVectorizer
# <p>Computers do not <em>understand</em> text. These are machines only capable of understanding numbers and performing numerical computation. Hence, we must convert our textual plot summaries to numbers for the computer to be able to extract meaning from them. One simple method of doing this would be to count all the occurrences of each word in the entire vocabulary and return the counts in a vector. Enter <code>CountVectorizer</code>.</p>
# <p>Consider the word 'the'. It appears quite frequently in almost all movie plots and will have a high count in each case. But obviously, it isn't the theme of all the movies! <a href="https://campus.datacamp.com/courses/natural-language-processing-fundamentals-in-python/simple-topic-identification?ex=11">Term Frequency-Inverse Document Frequency</a> (TF-IDF) is one method which overcomes the shortcomings of <code>CountVectorizer</code>. The Term Frequency of a word is the measure of how often it appears in a document, while the Inverse Document Frequency is the parameter which reduces the importance of a word if it frequently appears in several documents.</p>
# <p>For example, when we apply the TF-IDF on the first 3 sentences from the plot of <em>The Wizard of Oz</em>, we are told that the most important word there is 'Toto', the pet dog of the lead character. This is because the movie begins with 'Toto' biting someone due to which the journey of Oz begins!</p>
# <p>In simplest terms, TF-IDF recognizes words which are unique and important to any given document. Let's create one for our purposes.</p>

# %%
# Import TfidfVectorizer to create TF-IDF vectors
# ... YOUR CODE FOR TASK 6 ...

from sklearn.feature_extraction.text import TfidfVectorizer

# Instantiate TfidfVectorizer object with stopwords and tokenizer
# parameters for efficient processing of text
tfidf_vectorizer = TfidfVectorizer(max_df=0.95,
                                 stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem,
                                 ngram_range=(1,2))

# %% [markdown]
# ## 7. Fit transform TfidfVectorizer
# <p>Once we create a TF-IDF Vectorizer, we must fit the text to it and then transform the text to produce the corresponding numeric form of the data which the computer will be able to understand and derive meaning from. To do this, we use the <code>fit_transform()</code> method of the <code>TfidfVectorizer</code> object. </p>
# <p>If we observe the <code>TfidfVectorizer</code> object we created, we come across a parameter stopwords. 'stopwords' are those words in a given text which do not contribute considerably towards the meaning of the sentence and are generally grammatical filler words. For example, in the sentence 'Dorothy Gale lives with her dog Toto on the farm of her Aunt Em and Uncle Henry', we could drop the words 'her' and 'the', and still have a similar overall meaning to the sentence. Thus, 'her' and 'the' are stopwords and can be conveniently dropped from the sentence. </p>
# <p>On setting the stopwords to 'english', we direct the vectorizer to drop all stopwords from a pre-defined list of English language stopwords present in the nltk module. Another parameter, <code>ngram_range</code>, defines the length of the ngrams to be formed while vectorizing the text.</p>

# %%
# Fit and transform the tfidf_vectorizer with the "plot" of each movie
# to create a vector representation of the plot summaries
tfidf_matrix = tfidf_vectorizer.fit_transform([x for x in movies_df["plot"]])

print(tfidf_matrix.shape)
# Out:
# C:\Users\hjp28\anaconda\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# (10712, 251678)

# %% [markdown]
# ## 8. Import KMeans and create clusters
# <p>To determine how closely one movie is related to the other by the help of unsupervised learning, we can use clustering techniques. Clustering is the method of grouping together a number of items such that they exhibit similar properties. According to the measure of similarity desired, a given sample of items can have one or more clusters. </p>
# <p>A good basis of clustering in our dataset could be the genre of the movies. Say we could have a cluster '0' which holds movies of the 'Drama' genre. We would expect movies like <em>Chinatown</em> or <em>Psycho</em> to belong to this cluster. Similarly, the cluster '1' in this project holds movies which belong to the 'Adventure' genre (<em>Lawrence of Arabia</em> and the <em>Raiders of the Lost Ark</em>, for example).</p>
# <p>K-means is an algorithm which helps us to implement clustering in Python. The name derives from its method of implementation: the given sample is divided into <b><i>K</i></b> clusters where each cluster is denoted by the <b><i>mean</i></b> of all the items lying in that cluster. </p>
# <p>We get the following distribution for the clusters:</p>
# <p><img src="https://assets.datacamp.com/production/project_648/img/bar_clusters.png" alt="bar graph of clusters"></p>

# %%
from sklearn.metrics.pairwise import linear_kernel

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_sim[0]
movies_df = movies_df.reset_index(drop=True)
titles = movies_df['original_title']
indices = pd.Series(movies_df.index, index=movies_df['original_title'])

def get_recommendations(original_title):
    idx = indices[original_title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)
    sim_scores = sim_scores[1:10]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

get_recommendations('Toy Story')
# Out:
# 1818                     Toy Story 2
# 6545                     Toy Story 3
# 4835          The 40 Year Old Virgin
# 312                           Malice
# 8514                       Small Fry
# 1221                  Pretty in Pink
# 631            Rebel Without a Cause
# 3357    How to Lose a Guy in 10 Days
# 1143                       Condorman
# Name: original_title, dtype: object

# %% [markdown]
# ## 9. Calculate similarity distance
# <p>Consider the following two sentences from the movie <em>The Wizard of Oz</em>: </p>
# <blockquote>
#   <p>"they find in the Emerald City"</p>
#   <p>"they finally reach the Emerald City"</p>
# </blockquote>
# <p>If we put the above sentences in a <code>CountVectorizer</code>, the vocabulary produced would be "they, find, in, the, Emerald, City, finally, reach" and the vectors for each sentence would be as follows: </p>
# <blockquote>
#   <p>1, 1, 1, 1, 1, 1, 0, 0</p>
#   <p>1, 0, 0, 1, 1, 1, 1, 1</p>
# </blockquote>
# <p>When we calculate the cosine angle formed between the vectors represented by the above, we get a score of 0.667. This means the above sentences are very closely related. <em>Similarity distance</em> is 1 - <a href="https://en.wikipedia.org/wiki/Cosine_similarity">cosine similarity angle</a>. This follows from that if the vectors are similar, the cosine of their angle would be 1 and hence, the distance between then would be 1 - 1 = 0.</p>
# <p>Let's calculate the similarity distance for all of our movies.</p>

# %%
# Import cosine_similarity to calculate similarity of movie plots
from sklearn.metrics.pairwise import cosine_similarity

# Calculate the similarity distance
similarity_distance = 1 - cosine_similarity(tfidf_matrix)

print(len(similarity_distance[0]))
# Out:
# 10712

# %% [markdown]
# ## 10. Import Matplotlib, Linkage, and Dendrograms
# <p>We shall now create a tree-like diagram (called a dendrogram) of the movie titles to help us understand the level of similarity between them visually. Dendrograms help visualize the results of hierarchical clustering, which is an alternative to k-means clustering. Two pairs of movies at the same level of hierarchical clustering are expected to have similar strength of similarity between the corresponding pairs of movies. For example, the movie <em>Fargo</em> would be as similar to <em>North By Northwest</em> as the movie <em>Platoon</em> is to <em>Saving Private Ryan</em>, given both the pairs exhibit the same level of the hierarchy.</p>
# <p>Let's import the modules we'll need to create our dendrogram.</p>

# %%
# Import matplotlib.pyplot for plotting graphs
# ... YOUR CODE FOR TASK 10 ...

import matplotlib.pyplot as plt

# Configure matplotlib to display the output inline
# %matplotlib inline

# Import modules necessary to plot dendrogram
# ... YOUR CODE FOR TASK 10 ...

from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import linkage

# %% [markdown]
# ## 11. Create merging and plot dendrogram
# <p>We shall plot a dendrogram of the movies whose similarity measure will be given by the similarity distance we previously calculated. The lower the similarity distance between any two movies, the lower their linkage will make an intercept on the y-axis. For instance, the lowest dendrogram linkage we shall discover will be between the movies, <em>It's a Wonderful Life</em> and <em>A Place in the Sun</em>. This indicates that the movies are very similar to each other in their plots.</p>

# %%
# Create mergings matrix 
mergings = linkage(similarity_distance, method='complete')

# Plot the dendrogram, using title as label column
dendrogram_ = dendrogram(mergings,
               labels=[x for x in movies_df["title"]],
               leaf_rotation=90,
               leaf_font_size=8,
)

# Adjust the plot
fig = plt.gcf()
_ = [lbl.set_color('r') for lbl in plt.gca().get_xmajorticklabels()]
fig.set_size_inches(108, 21)

# Show the plotted dendrogram
plt.show()

# %% [markdown]
# ## 12. Which movies are most similar?
# <p>We can now determine the similarity between movies based on their plots! To wrap up, let's answer one final question: which movie is most similar to the movie <em>Braveheart</em>?</p>

# %%
# Answer the question 
ans = "Gladiator"
print(ans)
# Out:
# Gladiator
